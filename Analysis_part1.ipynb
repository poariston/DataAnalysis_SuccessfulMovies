# %% [markdown]
# ## Final Project Submission
#
# Please fill out:
# * Student name: Pierre-Olivier Ariston
# * Student pace:  part time
# * Scheduled project review date/time:
# * Instructor name: Eli
# * Blog post URL:

# %% [markdown]
# ### Importing and exploring the input datasets ...

# %%
import pandas as pd
df_rt_movie = pd.read_csv('Data/rt.movie_info.tsv',sep='\t')
print(df_rt_movie.shape)
df_rt_movie.head()
# Out:
# (1560, 12)
#    id                                           synopsis rating  \
# 0   1  This gritty, fast-paced, and innovative police...      R
# 1   3  New York City, not-too-distant-future: Eric Pa...      R
# 2   5  Illeana Douglas delivers a superb performance ...      R
# 3   6  Michael Douglas runs afoul of a treacherous su...      R
# 4   7                                                NaN     NR
#
#                                  genre          director  \
# 0  Action and Adventure|Classics|Drama  William Friedkin
# 1    Drama|Science Fiction and Fantasy  David Cronenberg
# 2    Drama|Musical and Performing Arts    Allison Anders
# 3           Drama|Mystery and Suspense    Barry Levinson
# 4                        Drama|Romance    Rodney Bennett
#
#                             writer  theater_date      dvd_date currency  \
# 0                   Ernest Tidyman   Oct 9, 1971  Sep 25, 2001      NaN
# 1     David Cronenberg|Don DeLillo  Aug 17, 2012   Jan 1, 2013        $
# 2                   Allison Anders  Sep 13, 1996  Apr 18, 2000      NaN
# 3  Paul Attanasio|Michael Crichton   Dec 9, 1994  Aug 27, 1997      NaN
# 4                     Giles Cooper           NaN           NaN      NaN
#
#   box_office      runtime             studio
# 0        NaN  104 minutes                NaN
# 1    600,000  108 minutes  Entertainment One
# 2        NaN  116 minutes                NaN
# 3        NaN  128 minutes                NaN
# 4        NaN  200 minutes                NaN

# %%
df_rt_rev = pd.read_csv('Data/rt.reviews.tsv',sep='\t',encoding = 'latin-1')
# had to change encoding from default utf-8 to latin-1
print(df_rt_rev.shape)
df_rt_rev.head()
# Out:
# (54432, 8)
#    id                                             review rating   fresh  \
# 0   3  A distinctly gallows take on contemporary fina...    3/5   fresh
# 1   3  It's an allegory in search of a meaning that n...    NaN  rotten
# 2   3  ... life lived in a bubble in financial dealin...    NaN   fresh
# 3   3  Continuing along a line introduced in last yea...    NaN   fresh
# 4   3             ... a perverse twist on neorealism...     NaN   fresh
#
#            critic  top_critic         publisher               date
# 0      PJ Nabarro           0   Patrick Nabarro  November 10, 2018
# 1  Annalee Newitz           0           io9.com       May 23, 2018
# 2    Sean Axmaker           0  Stream on Demand    January 4, 2018
# 3   Daniel Kasman           0              MUBI  November 16, 2017
# 4             NaN           0      Cinema Scope   October 12, 2017

# %%
df_imdb_basics = pd.read_csv('Data/imdb.name.basics.csv')
print(df_imdb_basics.shape)
df_imdb_basics.head()
# Out:
# (606648, 6)
#       nconst       primary_name  birth_year  death_year  \
# 0  nm0061671  Mary Ellen Bauder         NaN         NaN
# 1  nm0061865       Joseph Bauer         NaN         NaN
# 2  nm0062070         Bruce Baum         NaN         NaN
# 3  nm0062195       Axel Baumann         NaN         NaN
# 4  nm0062798        Pete Baxter         NaN         NaN
#
#                                  primary_profession  \
# 0         miscellaneous,production_manager,producer
# 1        composer,music_department,sound_department
# 2                        miscellaneous,actor,writer
# 3  camera_department,cinematographer,art_department
# 4  production_designer,art_department,set_decorator
#
#                           known_for_titles
# 0  tt0837562,tt2398241,tt0844471,tt0118553
# 1  tt0896534,tt6791238,tt0287072,tt1682940
# 2  tt1470654,tt0363631,tt0104030,tt0102898
# 3  tt0114371,tt2004304,tt1618448,tt1224387
# 4  tt0452644,tt0452692,tt3458030,tt2178256

# %%
df_imdb_akas = pd.read_csv('Data/imdb.title.akas.csv')
print(df_imdb_akas.shape)
df_imdb_akas.head()
# Out:
# (331703, 8)
#     title_id  ordering                                    title region  \
# 0  tt0369610        10                            Джурасик свят     BG
# 1  tt0369610        11                        Jurashikku warudo     JP
# 2  tt0369610        12  Jurassic World: O Mundo dos Dinossauros     BR
# 3  tt0369610        13                  O Mundo dos Dinossauros     BR
# 4  tt0369610        14                           Jurassic World     FR
#
#   language        types   attributes  is_original_title
# 0       bg          NaN          NaN                0.0
# 1      NaN  imdbDisplay          NaN                0.0
# 2      NaN  imdbDisplay          NaN                0.0
# 3      NaN          NaN  short title                0.0
# 4      NaN  imdbDisplay          NaN                0.0

# %%
df_imdb_basics = pd.read_csv('Data/imdb.title.basics.csv')
print(df_imdb_basics.shape)
df_imdb_basics.head()
# Out:
# (146144, 6)
#       tconst                    primary_title              original_title  \
# 0  tt0063540                        Sunghursh                   Sunghursh
# 1  tt0066787  One Day Before the Rainy Season             Ashad Ka Ek Din
# 2  tt0069049       The Other Side of the Wind  The Other Side of the Wind
# 3  tt0069204                  Sabse Bada Sukh             Sabse Bada Sukh
# 4  tt0100275         The Wandering Soap Opera       La Telenovela Errante
#
#    start_year  runtime_minutes                genres
# 0        2013            175.0    Action,Crime,Drama
# 1        2019            114.0       Biography,Drama
# 2        2018            122.0                 Drama
# 3        2018              NaN          Comedy,Drama
# 4        2017             80.0  Comedy,Drama,Fantasy

# %%
df_imdb_crew = pd.read_csv('Data/imdb.title.crew.csv')
print(df_imdb_crew.shape)
df_imdb_crew.head()
# Out:
# (146144, 3)
#       tconst                      directors              writers
# 0  tt0285252                      nm0899854            nm0899854
# 1  tt0438973                            NaN  nm0175726,nm1802864
# 2  tt0462036                      nm1940585            nm1940585
# 3  tt0835418                      nm0151540  nm0310087,nm0841532
# 4  tt0878654  nm0089502,nm2291498,nm2292011            nm0284943

# %%
df_imdb_pcpals = pd.read_csv('Data/imdb.title.principals.csv')
print(df_imdb_pcpals.shape)
df_imdb_pcpals.head()
# Out:
# (1028186, 6)
#       tconst  ordering     nconst  category       job        characters
# 0  tt0111414         1  nm0246005     actor       NaN       ["The Man"]
# 1  tt0111414         2  nm0398271  director       NaN               NaN
# 2  tt0111414         3  nm3739909  producer  producer               NaN
# 3  tt0323808        10  nm0059247    editor       NaN               NaN
# 4  tt0323808         1  nm3579312   actress       NaN  ["Beth Boothby"]

# %%
df_imdb_ratings =  pd.read_csv('Data/imdb.title.ratings.csv')
print(df_imdb_ratings.shape)
df_imdb_ratings.head()
# Out:
# (73856, 3)
#        tconst  averagerating  numvotes
# 0  tt10356526            8.3        31
# 1  tt10384606            8.9       559
# 2   tt1042974            6.4        20
# 3   tt1043726            4.2     50352
# 4   tt1060240            6.5        21

# %%
df_bom =  pd.read_csv('Data/bom.movie_gross.csv')
print(df_bom.shape)
df_bom.head()
# Out:
# (3387, 5)
#                                          title studio  domestic_gross  \
# 0                                  Toy Story 3     BV     415000000.0
# 1                   Alice in Wonderland (2010)     BV     334200000.0
# 2  Harry Potter and the Deathly Hallows Part 1     WB     296000000.0
# 3                                    Inception     WB     292600000.0
# 4                          Shrek Forever After   P/DW     238700000.0
#
#   foreign_gross  year
# 0     652000000  2010
# 1     691300000  2010
# 2     664300000  2010
# 3     535700000  2010
# 4     513900000  2010

# %%
df_tmdb = pd.read_csv('Data/tmdb.movies.csv')
print(df_tmdb.shape)
df_tmdb.head()
# Out:
# (26517, 10)
#    Unnamed: 0            genre_ids     id original_language  \
# 0           0      [12, 14, 10751]  12444                en
# 1           1  [14, 12, 16, 10751]  10191                en
# 2           2        [12, 28, 878]  10138                en
# 3           3      [16, 35, 10751]    862                en
# 4           4        [28, 878, 12]  27205                en
#
#                                  original_title  popularity release_date  \
# 0  Harry Potter and the Deathly Hallows: Part 1      33.533   2010-11-19
# 1                      How to Train Your Dragon      28.734   2010-03-26
# 2                                    Iron Man 2      28.515   2010-05-07
# 3                                     Toy Story      28.005   1995-11-22
# 4                                     Inception      27.920   2010-07-16
#
#                                           title  vote_average  vote_count
# 0  Harry Potter and the Deathly Hallows: Part 1           7.7       10788
# 1                      How to Train Your Dragon           7.7        7610
# 2                                    Iron Man 2           6.8       12368
# 3                                     Toy Story           7.9       10174
# 4                                     Inception           8.3       22186

# %%
df_budgets = pd.read_csv('Data/tn.movie_budgets.csv')
print(df_budgets.shape)
df_budgets.head()
# Out:
# (5782, 6)
#    id  release_date                                        movie  \
# 0   1  Dec 18, 2009                                       Avatar
# 1   2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2   3   Jun 7, 2019                                 Dark Phoenix
# 3   4   May 1, 2015                      Avengers: Age of Ultron
# 4   5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
#
#   production_budget domestic_gross worldwide_gross
# 0      $425,000,000   $760,507,625  $2,776,345,279
# 1      $410,600,000   $241,063,875  $1,045,663,875
# 2      $350,000,000    $42,762,350    $149,762,350
# 3      $330,600,000   $459,005,868  $1,403,013,963
# 4      $317,000,000   $620,181,382  $1,316,721,747

# %% [markdown]
# ### The question is: what type of films are currently doing the best at the box office?
# 1. indicator of how good a movie is doing = earnings - cost  or earning/cost
# 2. parameters describing type of movie:
# actor, director, writer, reviews, genre
#
# Data I need to gather: movie identifier - earnings - cost - actor - director - writer - reviews - genre
#
# Starting with the tn.movie_budgets for earnings and cost info ) and the imdb data (for genre information)

# %% [markdown]
# ### Data cleaning

# %%
df1=df_budgets.copy(deep=True) # deep copy of df_budgets to preserve original dataset 
# Looking for Nan values
df1.isnull().any()
# Out:
# id                   False
# release_date         False
# movie                False
# production_budget    False
# domestic_gross       False
# worldwide_gross      False
# dtype: bool

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5782 entries, 0 to 5781
# Data columns (total 6 columns):
# id                   5782 non-null int64
# release_date         5782 non-null object
# movie                5782 non-null object
# production_budget    5782 non-null object
# domestic_gross       5782 non-null object
# worldwide_gross      5782 non-null object
# dtypes: int64(1), object(5)
# memory usage: 271.2+ KB

# %%
# looking for duplicated movies
df1['movie'].duplicated().any()
# Out:
# True

# %%
df1[df1['movie'].duplicated()]
# Out:
#        id  release_date                       movie production_budget  \
# 273    74  May 19, 1998                    Godzilla      $125,000,000
# 408     9  Nov 21, 2018                  Robin Hood       $99,000,000
# 484    85   Jul 8, 2005              Fantastic Four       $87,500,000
# 543    44   May 7, 1999                   The Mummy       $80,000,000
# 707     8  Jun 13, 1997                    Hercules       $70,000,000
# ...   ...           ...                         ...               ...
# 5668   69  Nov 16, 1942                  Cat People          $134,000
# 5676   77   Oct 1, 1968    Night of the Living Dead          $114,000
# 5677   78   Feb 8, 1915       The Birth of a Nation          $110,000
# 5699  100  Aug 30, 1972  The Last House on the Left           $87,000
# 5718   19  Feb 22, 2008                  The Signal           $50,000
#
#      domestic_gross worldwide_gross
# 273    $136,314,294    $376,000,000
# 408     $30,824,628     $84,747,441
# 484    $154,696,080    $333,132,750
# 543    $155,385,488    $416,385,488
# 707     $99,112,101    $250,700,000
# ...             ...             ...
# 5668     $4,000,000      $8,000,000
# 5676    $12,087,064     $30,087,064
# 5677    $10,000,000     $11,000,000
# 5699     $3,100,000      $3,100,000
# 5718       $251,150        $406,299
#
# [84 rows x 6 columns]

# %% [markdown]
# #### 84 duplicates. Why?

# %%
df1[df1['movie'] == 'Godzilla']
# Out:
#      id  release_date     movie production_budget domestic_gross  \
# 140  41  May 16, 2014  Godzilla      $160,000,000   $200,676,069
# 273  74  May 19, 1998  Godzilla      $125,000,000   $136,314,294
#
#     worldwide_gross
# 140    $529,076,069
# 273    $376,000,000

# %%
df1[df1['movie'] == 'Robin Hood']
# Out:
#      id  release_date       movie production_budget domestic_gross  \
# 38   39  May 14, 2010  Robin Hood      $210,000,000   $105,487,148
# 408   9  Nov 21, 2018  Robin Hood       $99,000,000    $30,824,628
#
#     worldwide_gross
# 38     $322,459,006
# 408     $84,747,441

# %%
df1[df1['movie'] == 'The Last House on the Left']
# Out:
#        id  release_date                       movie production_budget  \
# 3043   44  Mar 13, 2009  The Last House on the Left       $15,000,000
# 5699  100  Aug 30, 1972  The Last House on the Left           $87,000
#
#      domestic_gross worldwide_gross
# 3043    $32,752,215     $46,526,243
# 5699     $3,100,000      $3,100,000

# %% [markdown]
# ####  It seems like the combination of the movie and the release date gives a unique identifier to each movie.
# #### With a unique identifier, I wil be able to join this data frame with others.
# ### Engineering of a new variable: 'movie_and_date'

# %%
#make sure  'movie' is a string
df1=df1.astype({'movie':'str'})

type(df1['movie'][0])
# Out:
# str

# %%
# transform 'realease date' into a timestamp to make sure it is consistent.
df1['release_date'] = pd.to_datetime(df1['release_date'])

# %%
df1.release_date[0]
# Out:
# Timestamp('2009-12-18 00:00:00')

# %%
type(df1.release_date[0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
str(df1.release_date[0])[0:4]
# Out:
# '2009'

# %%
df1.index
# Out:
# RangeIndex(start=0, stop=5782, step=1)

# %%
# taking the first 4 digit (year) out of the timestamp
df1['release_year'] = [ str(df1['release_date'][x])[0:4]  for x in df1.index ]
df1
# Out:
#       id release_date                                        movie  \
# 0      1   2009-12-18                                       Avatar
# 1      2   2011-05-20  Pirates of the Caribbean: On Stranger Tides
# 2      3   2019-06-07                                 Dark Phoenix
# 3      4   2015-05-01                      Avengers: Age of Ultron
# 4      5   2017-12-15            Star Wars Ep. VIII: The Last Jedi
# ...   ..          ...                                          ...
# 5777  78   2018-12-31                                       Red 11
# 5778  79   1999-04-02                                    Following
# 5779  80   2005-07-13                Return to the Land of Wonders
# 5780  81   2015-09-29                         A Plague So Pleasant
# 5781  82   2005-08-05                            My Date With Drew
#
#      production_budget domestic_gross worldwide_gross release_year
# 0         $425,000,000   $760,507,625  $2,776,345,279         2009
# 1         $410,600,000   $241,063,875  $1,045,663,875         2011
# 2         $350,000,000    $42,762,350    $149,762,350         2019
# 3         $330,600,000   $459,005,868  $1,403,013,963         2015
# 4         $317,000,000   $620,181,382  $1,316,721,747         2017
# ...                ...            ...             ...          ...
# 5777            $7,000             $0              $0         2018
# 5778            $6,000        $48,482        $240,495         1999
# 5779            $5,000         $1,338          $1,338         2005
# 5780            $1,400             $0              $0         2015
# 5781            $1,100       $181,041        $181,041         2005
#
# [5782 rows x 7 columns]

# %%
# concatenate movie and date
df1['movie_and_date'] = df1['movie'] + '_' + df1['release_year']

# %%
df1.head()
# Out:
#    id release_date                                        movie  \
# 0   1   2009-12-18                                       Avatar
# 1   2   2011-05-20  Pirates of the Caribbean: On Stranger Tides
# 2   3   2019-06-07                                 Dark Phoenix
# 3   4   2015-05-01                      Avengers: Age of Ultron
# 4   5   2017-12-15            Star Wars Ep. VIII: The Last Jedi
#
#   production_budget domestic_gross worldwide_gross release_year  \
# 0      $425,000,000   $760,507,625  $2,776,345,279         2009
# 1      $410,600,000   $241,063,875  $1,045,663,875         2011
# 2      $350,000,000    $42,762,350    $149,762,350         2019
# 3      $330,600,000   $459,005,868  $1,403,013,963         2015
# 4      $317,000,000   $620,181,382  $1,316,721,747         2017
#
#                                      movie_and_date
# 0                                       Avatar_2009
# 1  Pirates of the Caribbean: On Stranger Tides_2011
# 2                                 Dark Phoenix_2019
# 3                      Avengers: Age of Ultron_2015
# 4            Star Wars Ep. VIII: The Last Jedi_2017

# %%
df1['movie_and_date'][0]
# Out:
# 'Avatar_2009'

# %% [markdown]
# ### Output of df1 dataframe as a csv file. Will be used as inut to Analysis_part3.ipynb

# %%
# output to file. I will start over from this point in Analysis_Part3.ipynb
df1.to_csv('Data/df1.csv')

# %%
# preparing for join
df1= df1.set_index('movie_and_date')

# %%
df1
# Out:
#                                                   id release_date  \
# movie_and_date
# Avatar_2009                                        1   2009-12-18
# Pirates of the Caribbean: On Stranger Tides_2011   2   2011-05-20
# Dark Phoenix_2019                                  3   2019-06-07
# Avengers: Age of Ultron_2015                       4   2015-05-01
# Star Wars Ep. VIII: The Last Jedi_2017             5   2017-12-15
# ...                                               ..          ...
# Red 11_2018                                       78   2018-12-31
# Following_1999                                    79   1999-04-02
# Return to the Land of Wonders_2005                80   2005-07-13
# A Plague So Pleasant_2015                         81   2015-09-29
# My Date With Drew_2005                            82   2005-08-05
#
#                                                                                         movie  \
# movie_and_date
# Avatar_2009                                                                            Avatar
# Pirates of the Caribbean: On Stranger Tides_2011  Pirates of the Caribbean: On Stranger Tides
# Dark Phoenix_2019                                                                Dark Phoenix
# Avengers: Age of Ultron_2015                                          Avengers: Age of Ultron
# Star Wars Ep. VIII: The Last Jedi_2017                      Star Wars Ep. VIII: The Last Jedi
# ...                                                                                       ...
# Red 11_2018                                                                            Red 11
# Following_1999                                                                      Following
# Return to the Land of Wonders_2005                              Return to the Land of Wonders
# A Plague So Pleasant_2015                                                A Plague So Pleasant
# My Date With Drew_2005                                                      My Date With Drew
#
#                                                  production_budget  \
# movie_and_date
# Avatar_2009                                           $425,000,000
# Pirates of the Caribbean: On Stranger Tides_2011      $410,600,000
# Dark Phoenix_2019                                     $350,000,000
# Avengers: Age of Ultron_2015                          $330,600,000
# Star Wars Ep. VIII: The Last Jedi_2017                $317,000,000
# ...                                                            ...
# Red 11_2018                                                 $7,000
# Following_1999                                              $6,000
# Return to the Land of Wonders_2005                          $5,000
# A Plague So Pleasant_2015                                   $1,400
# My Date With Drew_2005                                      $1,100
#
#                                                  domestic_gross  \
# movie_and_date
# Avatar_2009                                        $760,507,625
# Pirates of the Caribbean: On Stranger Tides_2011   $241,063,875
# Dark Phoenix_2019                                   $42,762,350
# Avengers: Age of Ultron_2015                       $459,005,868
# Star Wars Ep. VIII: The Last Jedi_2017             $620,181,382
# ...                                                         ...
# Red 11_2018                                                  $0
# Following_1999                                          $48,482
# Return to the Land of Wonders_2005                       $1,338
# A Plague So Pleasant_2015                                    $0
# My Date With Drew_2005                                 $181,041
#
#                                                  worldwide_gross release_year
# movie_and_date
# Avatar_2009                                       $2,776,345,279         2009
# Pirates of the Caribbean: On Stranger Tides_2011  $1,045,663,875         2011
# Dark Phoenix_2019                                   $149,762,350         2019
# Avengers: Age of Ultron_2015                      $1,403,013,963         2015
# Star Wars Ep. VIII: The Last Jedi_2017            $1,316,721,747         2017
# ...                                                          ...          ...
# Red 11_2018                                                   $0         2018
# Following_1999                                          $240,495         1999
# Return to the Land of Wonders_2005                        $1,338         2005
# A Plague So Pleasant_2015                                     $0         2015
# My Date With Drew_2005                                  $181,041         2005
#
# [5782 rows x 7 columns]

# %%
# Starting from the imdb basics file
df2 = df_imdb_basics.copy(deep = True)  # deep copy of df_imdb_basics to preserve original dataset

# %%
# compare the 2 titles columns.
df2[ df2['primary_title'] != df2['original_title'] ]
# Out:
#            tconst                       primary_title  \
# 1       tt0066787     One Day Before the Rainy Season
# 4       tt0100275            The Wandering Soap Opera
# 11      tt0154039                So Much for Justice!
# 13      tt0162942        Children of the Green Dragon
# 15      tt0176694                  The Tragedy of Man
# ...           ...                                 ...
# 146026  tt9899938          Journey of the Sky Goddess
# 146028  tt9900060  Lupin the Third: Fujiko Mine's Lie
# 146037  tt9900688                   Big Three Dragons
# 146121  tt9914254                       A Cherry Tale
# 146135  tt9916170                       The Rehearsal
#
#                              original_title  start_year  runtime_minutes  \
# 1                           Ashad Ka Ek Din        2019            114.0
# 4                     La Telenovela Errante        2017             80.0
# 11                           Oda az igazság        2010            100.0
# 13                 A zöld sárkány gyermekei        2010             89.0
# 15                      Az ember tragédiája        2011            160.0
# ...                                     ...         ...              ...
# 146026                  Kibaiyanse! Watashi        2019            116.0
# 146028  Lupin the IIIrd: Mine Fujiko no Uso        2019              NaN
# 146037                          Da San Yuan        2019            111.0
# 146121                    Kirsebæreventyret        2019             85.0
# 146135                             O Ensaio        2019             51.0
#
#                          genres
# 1               Biography,Drama
# 4          Comedy,Drama,Fantasy
# 11                      History
# 13                        Drama
# 15      Animation,Drama,History
# ...                         ...
# 146026             Comedy,Drama
# 146028    Adventure,Crime,Drama
# 146037                   Comedy
# 146121              Documentary
# 146135                    Drama
#
# [14504 rows x 6 columns]

# %% [markdown]
# #### Primary title seems to be English translation of the original title. Using the primary title to create unique identifier based on title and date.
# #### This identifier wil be used to join the df2 imdb data with the df1 'budgets' dataframe

# %%
print(type(df2['primary_title'][0]))
print(type(df2['start_year'][0]))

# changing start_year to a string format
df2= df2.astype({'start_year' : 'str'})

print(type(df2['primary_title'][0]))
print(type(df2['start_year'][0]))
# Out:
# <class 'str'>
# <class 'numpy.int64'>
# <class 'str'>
# <class 'str'>

# %%
df2.reset_index(inplace=True)
df2['movie_and_date'] = df2['primary_title'] + '_' + df2['start_year'] 
df2['movie_and_date'][0]
# Out:
# 'Sunghursh_2013'

# %%
df2 = df2.set_index('movie_and_date')
df2
# Out:
#                                                    index     tconst  \
# movie_and_date
# Sunghursh_2013                                         0  tt0063540
# One Day Before the Rainy Season_2019                   1  tt0066787
# The Other Side of the Wind_2018                        2  tt0069049
# Sabse Bada Sukh_2018                                   3  tt0069204
# The Wandering Soap Opera_2017                          4  tt0100275
# ...                                                  ...        ...
# Kuambil Lagi Hatiku_2019                          146139  tt9916538
# Rodolpho Teóphilo - O Legado de um Pioneiro_2015  146140  tt9916622
# Dankyavar Danka_2013                              146141  tt9916706
# 6 Gunn_2017                                       146142  tt9916730
# Chico Albuquerque - Revelações_2013               146143  tt9916754
#
#                                                                                 primary_title  \
# movie_and_date
# Sunghursh_2013                                                                      Sunghursh
# One Day Before the Rainy Season_2019                          One Day Before the Rainy Season
# The Other Side of the Wind_2018                                    The Other Side of the Wind
# Sabse Bada Sukh_2018                                                          Sabse Bada Sukh
# The Wandering Soap Opera_2017                                        The Wandering Soap Opera
# ...                                                                                       ...
# Kuambil Lagi Hatiku_2019                                                  Kuambil Lagi Hatiku
# Rodolpho Teóphilo - O Legado de um Pioneiro_2015  Rodolpho Teóphilo - O Legado de um Pioneiro
# Dankyavar Danka_2013                                                          Dankyavar Danka
# 6 Gunn_2017                                                                            6 Gunn
# Chico Albuquerque - Revelações_2013                            Chico Albuquerque - Revelações
#
#                                                                                original_title  \
# movie_and_date
# Sunghursh_2013                                                                      Sunghursh
# One Day Before the Rainy Season_2019                                          Ashad Ka Ek Din
# The Other Side of the Wind_2018                                    The Other Side of the Wind
# Sabse Bada Sukh_2018                                                          Sabse Bada Sukh
# The Wandering Soap Opera_2017                                           La Telenovela Errante
# ...                                                                                       ...
# Kuambil Lagi Hatiku_2019                                                  Kuambil Lagi Hatiku
# Rodolpho Teóphilo - O Legado de um Pioneiro_2015  Rodolpho Teóphilo - O Legado de um Pioneiro
# Dankyavar Danka_2013                                                          Dankyavar Danka
# 6 Gunn_2017                                                                            6 Gunn
# Chico Albuquerque - Revelações_2013                            Chico Albuquerque - Revelações
#
#                                                  start_year  runtime_minutes  \
# movie_and_date
# Sunghursh_2013                                         2013            175.0
# One Day Before the Rainy Season_2019                   2019            114.0
# The Other Side of the Wind_2018                        2018            122.0
# Sabse Bada Sukh_2018                                   2018              NaN
# The Wandering Soap Opera_2017                          2017             80.0
# ...                                                     ...              ...
# Kuambil Lagi Hatiku_2019                               2019            123.0
# Rodolpho Teóphilo - O Legado de um Pioneiro_2015       2015              NaN
# Dankyavar Danka_2013                                   2013              NaN
# 6 Gunn_2017                                            2017            116.0
# Chico Albuquerque - Revelações_2013                    2013              NaN
#
#                                                                 genres
# movie_and_date
# Sunghursh_2013                                      Action,Crime,Drama
# One Day Before the Rainy Season_2019                   Biography,Drama
# The Other Side of the Wind_2018                                  Drama
# Sabse Bada Sukh_2018                                      Comedy,Drama
# The Wandering Soap Opera_2017                     Comedy,Drama,Fantasy
# ...                                                                ...
# Kuambil Lagi Hatiku_2019                                         Drama
# Rodolpho Teóphilo - O Legado de um Pioneiro_2015           Documentary
# Dankyavar Danka_2013                                            Comedy
# 6 Gunn_2017                                                        NaN
# Chico Albuquerque - Revelações_2013                        Documentary
#
# [146144 rows x 7 columns]

# %% [markdown]
# #### Ready to join df1 (budget) and df2 (imdb_basics). Keep only the movies for which I have budget and imdb_basics info. So, inner join.

# %%
df3=df1.join(df2,how='inner')
df3
# Out:
#                                  id release_date                       movie  \
# movie_and_date
# #Horror_2015                     16   2015-11-20                     #Horror
# 10 Cloverfield Lane_2016         54   2016-03-11         10 Cloverfield Lane
# 10 Days in a Madhouse_2015       48   2015-11-11       10 Days in a Madhouse
# 12 Strong_2018                   64   2018-01-19                   12 Strong
# 12 Years a Slave_2013            18   2013-10-18            12 Years a Slave
# ...                              ..          ...                         ...
# Zookeeper_2011                   71   2011-07-08                   Zookeeper
# Zoolander 2_2016                 64   2016-02-12                 Zoolander 2
# Zootopia_2016                    57   2016-03-04                    Zootopia
# Zulu_2013                        82   2013-12-31                        Zulu
# xXx: Return of Xander Cage_2017  15   2017-01-20  xXx: Return of Xander Cage
#
#                                 production_budget domestic_gross  \
# movie_and_date
# #Horror_2015                           $1,500,000             $0
# 10 Cloverfield Lane_2016               $5,000,000    $72,082,999
# 10 Days in a Madhouse_2015            $12,000,000        $14,616
# 12 Strong_2018                        $35,000,000    $45,819,713
# 12 Years a Slave_2013                 $20,000,000    $56,671,993
# ...                                           ...            ...
# Zookeeper_2011                        $80,000,000    $80,360,866
# Zoolander 2_2016                      $50,000,000    $28,848,693
# Zootopia_2016                        $150,000,000   $341,268,248
# Zulu_2013                             $16,000,000             $0
# xXx: Return of Xander Cage_2017       $85,000,000    $44,898,413
#
#                                 worldwide_gross release_year  index  \
# movie_and_date
# #Horror_2015                                 $0         2015  61037
# 10 Cloverfield Lane_2016           $108,286,422         2016   5761
# 10 Days in a Madhouse_2015              $14,616         2015  59400
# 12 Strong_2018                      $71,118,378         2018   7385
# 12 Years a Slave_2013              $181,025,343         2013  25709
# ...                                         ...          ...    ...
# Zookeeper_2011                     $170,805,525         2011   5964
# Zoolander 2_2016                    $55,348,693         2016  10724
# Zootopia_2016                    $1,019,429,616         2016  49579
# Zulu_2013                            $1,844,228         2013  33517
# xXx: Return of Xander Cage_2017    $345,033,359         2017   6407
#
#                                     tconst               primary_title  \
# movie_and_date
# #Horror_2015                     tt3526286                     #Horror
# 10 Cloverfield Lane_2016         tt1179933         10 Cloverfield Lane
# 10 Days in a Madhouse_2015       tt3453052       10 Days in a Madhouse
# 12 Strong_2018                   tt1413492                   12 Strong
# 12 Years a Slave_2013            tt2024544            12 Years a Slave
# ...                                    ...                         ...
# Zookeeper_2011                   tt1222817                   Zookeeper
# Zoolander 2_2016                 tt1608290                 Zoolander 2
# Zootopia_2016                    tt2948356                    Zootopia
# Zulu_2013                        tt2249221                        Zulu
# xXx: Return of Xander Cage_2017  tt1293847  xXx: Return of Xander Cage
#
#                                              original_title start_year  \
# movie_and_date
# #Horror_2015                                        #Horror       2015
# 10 Cloverfield Lane_2016                10 Cloverfield Lane       2016
# 10 Days in a Madhouse_2015            10 Days in a Madhouse       2015
# 12 Strong_2018                                    12 Strong       2018
# 12 Years a Slave_2013                      12 Years a Slave       2013
# ...                                                     ...        ...
# Zookeeper_2011                                    Zookeeper       2011
# Zoolander 2_2016                                Zoolander 2       2016
# Zootopia_2016                                      Zootopia       2016
# Zulu_2013                                              Zulu       2013
# xXx: Return of Xander Cage_2017  xXx: Return of Xander Cage       2017
#
#                                  runtime_minutes                      genres
# movie_and_date
# #Horror_2015                               101.0          Crime,Drama,Horror
# 10 Cloverfield Lane_2016                   103.0        Drama,Horror,Mystery
# 10 Days in a Madhouse_2015                 111.0                       Drama
# 12 Strong_2018                             130.0        Action,Drama,History
# 12 Years a Slave_2013                      134.0     Biography,Drama,History
# ...                                          ...                         ...
# Zookeeper_2011                             102.0       Comedy,Family,Romance
# Zoolander 2_2016                           101.0                      Comedy
# Zootopia_2016                              108.0  Adventure,Animation,Comedy
# Zulu_2013                                  110.0        Crime,Drama,Thriller
# xXx: Return of Xander Cage_2017            107.0   Action,Adventure,Thriller
#
# [1547 rows x 14 columns]

# %% [markdown]
# #### At this point, we have 1547 movies with $ information and ability to join the imdb data based on the tconst column which is the imdb movie identifier.
# #### Let's use worldwide_gross / production_budget / movie_and_date to identify profitable movies
#
# #### Need to remove $ and , signs from worldwide_gross and production_budget

# %%
df3.astype({'production_budget':'str', 'domestic_gross':'str', 'worldwide_gross':'str',})
# Out:
#                                  id release_date                       movie  \
# movie_and_date
# #Horror_2015                     16   2015-11-20                     #Horror
# 10 Cloverfield Lane_2016         54   2016-03-11         10 Cloverfield Lane
# 10 Days in a Madhouse_2015       48   2015-11-11       10 Days in a Madhouse
# 12 Strong_2018                   64   2018-01-19                   12 Strong
# 12 Years a Slave_2013            18   2013-10-18            12 Years a Slave
# ...                              ..          ...                         ...
# Zookeeper_2011                   71   2011-07-08                   Zookeeper
# Zoolander 2_2016                 64   2016-02-12                 Zoolander 2
# Zootopia_2016                    57   2016-03-04                    Zootopia
# Zulu_2013                        82   2013-12-31                        Zulu
# xXx: Return of Xander Cage_2017  15   2017-01-20  xXx: Return of Xander Cage
#
#                                 production_budget domestic_gross  \
# movie_and_date
# #Horror_2015                           $1,500,000             $0
# 10 Cloverfield Lane_2016               $5,000,000    $72,082,999
# 10 Days in a Madhouse_2015            $12,000,000        $14,616
# 12 Strong_2018                        $35,000,000    $45,819,713
# 12 Years a Slave_2013                 $20,000,000    $56,671,993
# ...                                           ...            ...
# Zookeeper_2011                        $80,000,000    $80,360,866
# Zoolander 2_2016                      $50,000,000    $28,848,693
# Zootopia_2016                        $150,000,000   $341,268,248
# Zulu_2013                             $16,000,000             $0
# xXx: Return of Xander Cage_2017       $85,000,000    $44,898,413
#
#                                 worldwide_gross release_year  index  \
# movie_and_date
# #Horror_2015                                 $0         2015  61037
# 10 Cloverfield Lane_2016           $108,286,422         2016   5761
# 10 Days in a Madhouse_2015              $14,616         2015  59400
# 12 Strong_2018                      $71,118,378         2018   7385
# 12 Years a Slave_2013              $181,025,343         2013  25709
# ...                                         ...          ...    ...
# Zookeeper_2011                     $170,805,525         2011   5964
# Zoolander 2_2016                    $55,348,693         2016  10724
# Zootopia_2016                    $1,019,429,616         2016  49579
# Zulu_2013                            $1,844,228         2013  33517
# xXx: Return of Xander Cage_2017    $345,033,359         2017   6407
#
#                                     tconst               primary_title  \
# movie_and_date
# #Horror_2015                     tt3526286                     #Horror
# 10 Cloverfield Lane_2016         tt1179933         10 Cloverfield Lane
# 10 Days in a Madhouse_2015       tt3453052       10 Days in a Madhouse
# 12 Strong_2018                   tt1413492                   12 Strong
# 12 Years a Slave_2013            tt2024544            12 Years a Slave
# ...                                    ...                         ...
# Zookeeper_2011                   tt1222817                   Zookeeper
# Zoolander 2_2016                 tt1608290                 Zoolander 2
# Zootopia_2016                    tt2948356                    Zootopia
# Zulu_2013                        tt2249221                        Zulu
# xXx: Return of Xander Cage_2017  tt1293847  xXx: Return of Xander Cage
#
#                                              original_title start_year  \
# movie_and_date
# #Horror_2015                                        #Horror       2015
# 10 Cloverfield Lane_2016                10 Cloverfield Lane       2016
# 10 Days in a Madhouse_2015            10 Days in a Madhouse       2015
# 12 Strong_2018                                    12 Strong       2018
# 12 Years a Slave_2013                      12 Years a Slave       2013
# ...                                                     ...        ...
# Zookeeper_2011                                    Zookeeper       2011
# Zoolander 2_2016                                Zoolander 2       2016
# Zootopia_2016                                      Zootopia       2016
# Zulu_2013                                              Zulu       2013
# xXx: Return of Xander Cage_2017  xXx: Return of Xander Cage       2017
#
#                                  runtime_minutes                      genres
# movie_and_date
# #Horror_2015                               101.0          Crime,Drama,Horror
# 10 Cloverfield Lane_2016                   103.0        Drama,Horror,Mystery
# 10 Days in a Madhouse_2015                 111.0                       Drama
# 12 Strong_2018                             130.0        Action,Drama,History
# 12 Years a Slave_2013                      134.0     Biography,Drama,History
# ...                                          ...                         ...
# Zookeeper_2011                             102.0       Comedy,Family,Romance
# Zoolander 2_2016                           101.0                      Comedy
# Zootopia_2016                              108.0  Adventure,Animation,Comedy
# Zulu_2013                                  110.0        Crime,Drama,Thriller
# xXx: Return of Xander Cage_2017            107.0   Action,Adventure,Thriller
#
# [1547 rows x 14 columns]

# %%
df3.reset_index(inplace=True)
df3.index
# Out:
# RangeIndex(start=0, stop=1547, step=1)

# %%
# df3['production_budget'][0][1:]
df3['production_budget']= [df3['production_budget'][x][1:]for x in df3.index]

# %%
df3['domestic_gross']= [df3['domestic_gross'][x][1:]for x in df3.index]
df3['worldwide_gross']= [df3['worldwide_gross'][x][1:]for x in df3.index]

# %%
df3['production_budget']= [df3['production_budget'][x].replace(',','')for x in df3.index]

# %%
df3['domestic_gross']= [df3['domestic_gross'][x].replace(',','')for x in df3.index]
df3['worldwide_gross']= [df3['worldwide_gross'][x].replace(',','')for x in df3.index]

# %%
df3
# Out:
#                        movie_and_date  id release_date  \
# 0                        #Horror_2015  16   2015-11-20
# 1            10 Cloverfield Lane_2016  54   2016-03-11
# 2          10 Days in a Madhouse_2015  48   2015-11-11
# 3                      12 Strong_2018  64   2018-01-19
# 4               12 Years a Slave_2013  18   2013-10-18
# ...                               ...  ..          ...
# 1542                   Zookeeper_2011  71   2011-07-08
# 1543                 Zoolander 2_2016  64   2016-02-12
# 1544                    Zootopia_2016  57   2016-03-04
# 1545                        Zulu_2013  82   2013-12-31
# 1546  xXx: Return of Xander Cage_2017  15   2017-01-20
#
#                            movie production_budget domestic_gross  \
# 0                        #Horror           1500000              0
# 1            10 Cloverfield Lane           5000000       72082999
# 2          10 Days in a Madhouse          12000000          14616
# 3                      12 Strong          35000000       45819713
# 4               12 Years a Slave          20000000       56671993
# ...                          ...               ...            ...
# 1542                   Zookeeper          80000000       80360866
# 1543                 Zoolander 2          50000000       28848693
# 1544                    Zootopia         150000000      341268248
# 1545                        Zulu          16000000              0
# 1546  xXx: Return of Xander Cage          85000000       44898413
#
#      worldwide_gross release_year  index     tconst  \
# 0                  0         2015  61037  tt3526286
# 1          108286422         2016   5761  tt1179933
# 2              14616         2015  59400  tt3453052
# 3           71118378         2018   7385  tt1413492
# 4          181025343         2013  25709  tt2024544
# ...              ...          ...    ...        ...
# 1542       170805525         2011   5964  tt1222817
# 1543        55348693         2016  10724  tt1608290
# 1544      1019429616         2016  49579  tt2948356
# 1545         1844228         2013  33517  tt2249221
# 1546       345033359         2017   6407  tt1293847
#
#                    primary_title              original_title start_year  \
# 0                        #Horror                     #Horror       2015
# 1            10 Cloverfield Lane         10 Cloverfield Lane       2016
# 2          10 Days in a Madhouse       10 Days in a Madhouse       2015
# 3                      12 Strong                   12 Strong       2018
# 4               12 Years a Slave            12 Years a Slave       2013
# ...                          ...                         ...        ...
# 1542                   Zookeeper                   Zookeeper       2011
# 1543                 Zoolander 2                 Zoolander 2       2016
# 1544                    Zootopia                    Zootopia       2016
# 1545                        Zulu                        Zulu       2013
# 1546  xXx: Return of Xander Cage  xXx: Return of Xander Cage       2017
#
#       runtime_minutes                      genres
# 0               101.0          Crime,Drama,Horror
# 1               103.0        Drama,Horror,Mystery
# 2               111.0                       Drama
# 3               130.0        Action,Drama,History
# 4               134.0     Biography,Drama,History
# ...               ...                         ...
# 1542            102.0       Comedy,Family,Romance
# 1543            101.0                      Comedy
# 1544            108.0  Adventure,Animation,Comedy
# 1545            110.0        Crime,Drama,Thriller
# 1546            107.0   Action,Adventure,Thriller
#
# [1547 rows x 15 columns]

# %% [markdown]
# #### Make sure $ amounts make sense

# %%
df3=df3.astype({'production_budget':'int', 'domestic_gross':'int', 'worldwide_gross':'int',})

# %%
df3
# Out:
#                        movie_and_date  id release_date  \
# 0                        #Horror_2015  16   2015-11-20
# 1            10 Cloverfield Lane_2016  54   2016-03-11
# 2          10 Days in a Madhouse_2015  48   2015-11-11
# 3                      12 Strong_2018  64   2018-01-19
# 4               12 Years a Slave_2013  18   2013-10-18
# ...                               ...  ..          ...
# 1542                   Zookeeper_2011  71   2011-07-08
# 1543                 Zoolander 2_2016  64   2016-02-12
# 1544                    Zootopia_2016  57   2016-03-04
# 1545                        Zulu_2013  82   2013-12-31
# 1546  xXx: Return of Xander Cage_2017  15   2017-01-20
#
#                            movie  production_budget  domestic_gross  \
# 0                        #Horror            1500000               0
# 1            10 Cloverfield Lane            5000000        72082999
# 2          10 Days in a Madhouse           12000000           14616
# 3                      12 Strong           35000000        45819713
# 4               12 Years a Slave           20000000        56671993
# ...                          ...                ...             ...
# 1542                   Zookeeper           80000000        80360866
# 1543                 Zoolander 2           50000000        28848693
# 1544                    Zootopia          150000000       341268248
# 1545                        Zulu           16000000               0
# 1546  xXx: Return of Xander Cage           85000000        44898413
#
#       worldwide_gross release_year  index     tconst  \
# 0                   0         2015  61037  tt3526286
# 1           108286422         2016   5761  tt1179933
# 2               14616         2015  59400  tt3453052
# 3            71118378         2018   7385  tt1413492
# 4           181025343         2013  25709  tt2024544
# ...               ...          ...    ...        ...
# 1542        170805525         2011   5964  tt1222817
# 1543         55348693         2016  10724  tt1608290
# 1544       1019429616         2016  49579  tt2948356
# 1545          1844228         2013  33517  tt2249221
# 1546        345033359         2017   6407  tt1293847
#
#                    primary_title              original_title start_year  \
# 0                        #Horror                     #Horror       2015
# 1            10 Cloverfield Lane         10 Cloverfield Lane       2016
# 2          10 Days in a Madhouse       10 Days in a Madhouse       2015
# 3                      12 Strong                   12 Strong       2018
# 4               12 Years a Slave            12 Years a Slave       2013
# ...                          ...                         ...        ...
# 1542                   Zookeeper                   Zookeeper       2011
# 1543                 Zoolander 2                 Zoolander 2       2016
# 1544                    Zootopia                    Zootopia       2016
# 1545                        Zulu                        Zulu       2013
# 1546  xXx: Return of Xander Cage  xXx: Return of Xander Cage       2017
#
#       runtime_minutes                      genres
# 0               101.0          Crime,Drama,Horror
# 1               103.0        Drama,Horror,Mystery
# 2               111.0                       Drama
# 3               130.0        Action,Drama,History
# 4               134.0     Biography,Drama,History
# ...               ...                         ...
# 1542            102.0       Comedy,Family,Romance
# 1543            101.0                      Comedy
# 1544            108.0  Adventure,Animation,Comedy
# 1545            110.0        Crime,Drama,Thriller
# 1546            107.0   Action,Adventure,Thriller
#
# [1547 rows x 15 columns]

# %% [markdown]
# #### removing rows with zero $ values

# %%
df3=df3.loc[ (df3['production_budget']!=0) & (df3['domestic_gross']!=0) & (df3['worldwide_gross']!=0)]

# %%
df3
# Out:
#                        movie_and_date  id release_date  \
# 1            10 Cloverfield Lane_2016  54   2016-03-11
# 2          10 Days in a Madhouse_2015  48   2015-11-11
# 3                      12 Strong_2018  64   2018-01-19
# 4               12 Years a Slave_2013  18   2013-10-18
# 5                      127 Hours_2010   6   2010-11-05
# ...                               ...  ..          ...
# 1539            Zero Dark Thirty_2012  66   2012-12-19
# 1542                   Zookeeper_2011  71   2011-07-08
# 1543                 Zoolander 2_2016  64   2016-02-12
# 1544                    Zootopia_2016  57   2016-03-04
# 1546  xXx: Return of Xander Cage_2017  15   2017-01-20
#
#                            movie  production_budget  domestic_gross  \
# 1            10 Cloverfield Lane            5000000        72082999
# 2          10 Days in a Madhouse           12000000           14616
# 3                      12 Strong           35000000        45819713
# 4               12 Years a Slave           20000000        56671993
# 5                      127 Hours           18000000        18335230
# ...                          ...                ...             ...
# 1539            Zero Dark Thirty           52500000        95720716
# 1542                   Zookeeper           80000000        80360866
# 1543                 Zoolander 2           50000000        28848693
# 1544                    Zootopia          150000000       341268248
# 1546  xXx: Return of Xander Cage           85000000        44898413
#
#       worldwide_gross release_year  index     tconst  \
# 1           108286422         2016   5761  tt1179933
# 2               14616         2015  59400  tt3453052
# 3            71118378         2018   7385  tt1413492
# 4           181025343         2013  25709  tt2024544
# 5            60217171         2010   9126  tt1542344
# ...               ...          ...    ...        ...
# 1539        134612435         2012  17751  tt1790885
# 1542        170805525         2011   5964  tt1222817
# 1543         55348693         2016  10724  tt1608290
# 1544       1019429616         2016  49579  tt2948356
# 1546        345033359         2017   6407  tt1293847
#
#                    primary_title              original_title start_year  \
# 1            10 Cloverfield Lane         10 Cloverfield Lane       2016
# 2          10 Days in a Madhouse       10 Days in a Madhouse       2015
# 3                      12 Strong                   12 Strong       2018
# 4               12 Years a Slave            12 Years a Slave       2013
# 5                      127 Hours                   127 Hours       2010
# ...                          ...                         ...        ...
# 1539            Zero Dark Thirty            Zero Dark Thirty       2012
# 1542                   Zookeeper                   Zookeeper       2011
# 1543                 Zoolander 2                 Zoolander 2       2016
# 1544                    Zootopia                    Zootopia       2016
# 1546  xXx: Return of Xander Cage  xXx: Return of Xander Cage       2017
#
#       runtime_minutes                      genres
# 1               103.0        Drama,Horror,Mystery
# 2               111.0                       Drama
# 3               130.0        Action,Drama,History
# 4               134.0     Biography,Drama,History
# 5                94.0   Adventure,Biography,Drama
# ...               ...                         ...
# 1539            157.0              Drama,Thriller
# 1542            102.0       Comedy,Family,Romance
# 1543            101.0                      Comedy
# 1544            108.0  Adventure,Animation,Comedy
# 1546            107.0   Action,Adventure,Thriller
#
# [1370 rows x 15 columns]

# %% [markdown]
# ### Feature engineering: 'profit', 'profit_ratio'
# The goal is to create features telling us if a movie was successful or not.

# %%
df4 = df3.copy()
df4
# Out:
#                        movie_and_date  id release_date  \
# 1            10 Cloverfield Lane_2016  54   2016-03-11
# 2          10 Days in a Madhouse_2015  48   2015-11-11
# 3                      12 Strong_2018  64   2018-01-19
# 4               12 Years a Slave_2013  18   2013-10-18
# 5                      127 Hours_2010   6   2010-11-05
# ...                               ...  ..          ...
# 1539            Zero Dark Thirty_2012  66   2012-12-19
# 1542                   Zookeeper_2011  71   2011-07-08
# 1543                 Zoolander 2_2016  64   2016-02-12
# 1544                    Zootopia_2016  57   2016-03-04
# 1546  xXx: Return of Xander Cage_2017  15   2017-01-20
#
#                            movie  production_budget  domestic_gross  \
# 1            10 Cloverfield Lane            5000000        72082999
# 2          10 Days in a Madhouse           12000000           14616
# 3                      12 Strong           35000000        45819713
# 4               12 Years a Slave           20000000        56671993
# 5                      127 Hours           18000000        18335230
# ...                          ...                ...             ...
# 1539            Zero Dark Thirty           52500000        95720716
# 1542                   Zookeeper           80000000        80360866
# 1543                 Zoolander 2           50000000        28848693
# 1544                    Zootopia          150000000       341268248
# 1546  xXx: Return of Xander Cage           85000000        44898413
#
#       worldwide_gross release_year  index     tconst  \
# 1           108286422         2016   5761  tt1179933
# 2               14616         2015  59400  tt3453052
# 3            71118378         2018   7385  tt1413492
# 4           181025343         2013  25709  tt2024544
# 5            60217171         2010   9126  tt1542344
# ...               ...          ...    ...        ...
# 1539        134612435         2012  17751  tt1790885
# 1542        170805525         2011   5964  tt1222817
# 1543         55348693         2016  10724  tt1608290
# 1544       1019429616         2016  49579  tt2948356
# 1546        345033359         2017   6407  tt1293847
#
#                    primary_title              original_title start_year  \
# 1            10 Cloverfield Lane         10 Cloverfield Lane       2016
# 2          10 Days in a Madhouse       10 Days in a Madhouse       2015
# 3                      12 Strong                   12 Strong       2018
# 4               12 Years a Slave            12 Years a Slave       2013
# 5                      127 Hours                   127 Hours       2010
# ...                          ...                         ...        ...
# 1539            Zero Dark Thirty            Zero Dark Thirty       2012
# 1542                   Zookeeper                   Zookeeper       2011
# 1543                 Zoolander 2                 Zoolander 2       2016
# 1544                    Zootopia                    Zootopia       2016
# 1546  xXx: Return of Xander Cage  xXx: Return of Xander Cage       2017
#
#       runtime_minutes                      genres
# 1               103.0        Drama,Horror,Mystery
# 2               111.0                       Drama
# 3               130.0        Action,Drama,History
# 4               134.0     Biography,Drama,History
# 5                94.0   Adventure,Biography,Drama
# ...               ...                         ...
# 1539            157.0              Drama,Thriller
# 1542            102.0       Comedy,Family,Romance
# 1543            101.0                      Comedy
# 1544            108.0  Adventure,Animation,Comedy
# 1546            107.0   Action,Adventure,Thriller
#
# [1370 rows x 15 columns]

# %%
df4['profit'] = df4['worldwide_gross']-df4['production_budget']
df4.head()
# Out:
#                movie_and_date  id release_date                  movie  \
# 1    10 Cloverfield Lane_2016  54   2016-03-11    10 Cloverfield Lane
# 2  10 Days in a Madhouse_2015  48   2015-11-11  10 Days in a Madhouse
# 3              12 Strong_2018  64   2018-01-19              12 Strong
# 4       12 Years a Slave_2013  18   2013-10-18       12 Years a Slave
# 5              127 Hours_2010   6   2010-11-05              127 Hours
#
#    production_budget  domestic_gross  worldwide_gross release_year  index  \
# 1            5000000        72082999        108286422         2016   5761
# 2           12000000           14616            14616         2015  59400
# 3           35000000        45819713         71118378         2018   7385
# 4           20000000        56671993        181025343         2013  25709
# 5           18000000        18335230         60217171         2010   9126
#
#       tconst          primary_title         original_title start_year  \
# 1  tt1179933    10 Cloverfield Lane    10 Cloverfield Lane       2016
# 2  tt3453052  10 Days in a Madhouse  10 Days in a Madhouse       2015
# 3  tt1413492              12 Strong              12 Strong       2018
# 4  tt2024544       12 Years a Slave       12 Years a Slave       2013
# 5  tt1542344              127 Hours              127 Hours       2010
#
#    runtime_minutes                     genres     profit
# 1            103.0       Drama,Horror,Mystery  103286422
# 2            111.0                      Drama  -11985384
# 3            130.0       Action,Drama,History   36118378
# 4            134.0    Biography,Drama,History  161025343
# 5             94.0  Adventure,Biography,Drama   42217171

# %% [markdown]
# #### Let's do some visualization of the $ data

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df4.sort_values(by = 'profit',inplace=True)
plt.figure(figsize =(16,20))
sns.barplot(x='profit',y='movie_and_date',data=df4)

plt.grid(zorder=0,color='b')
plt.yticks([])
plt.title("movies' profit", fontsize=14)
plt.xlabel("profit ", fontsize=14)
plt.ylabel("movies", fontsize=14)
# Out:
# Text(0, 0.5, 'movies')

# %% [markdown]
# ### Conclusion:
# #### Most movies have positive profit. It seems like the movie business is a good business to invest in.
#
# #### Let's now look at the profit in terms of a ratio between income and cost

# %%
df4['profit_ratio'] = df4['worldwide_gross']/df4['production_budget']
df4.sort_values(by = 'profit_ratio',inplace=True)
df4.head()
# Out:
#                          movie_and_date  id release_date  \
# 520                   Higher Power_2018  67   2018-05-11
# 1198  The Ghastly Love of Johnny X_2012  74   2012-10-26
# 2            10 Days in a Madhouse_2015  48   2015-11-11
# 119                        Area 51_2015  81   2015-05-15
# 434               Freaks of Nature_2015  83   2015-10-30
#
#                              movie  production_budget  domestic_gross  \
# 520                   Higher Power             500000             528
# 1198  The Ghastly Love of Johnny X            2000000            2436
# 2            10 Days in a Madhouse           12000000           14616
# 119                        Area 51            5000000            7556
# 434               Freaks of Nature           33000000           70958
#
#       worldwide_gross release_year  index     tconst  \
# 520               528         2018  49123  tt2924392
# 1198             2436         2012  16165  tt1754633
# 2               14616         2015  59400  tt3453052
# 119              7556         2015   8624  tt1519461
# 434             70958         2015  18716  tt1817771
#
#                      primary_title                original_title start_year  \
# 520                   Higher Power                  Higher Power       2018
# 1198  The Ghastly Love of Johnny X  The Ghastly Love of Johnny X       2012
# 2            10 Days in a Madhouse         10 Days in a Madhouse       2015
# 119                        Area 51                       Area 51       2015
# 434               Freaks of Nature              Freaks of Nature       2015
#
#       runtime_minutes                  genres    profit  profit_ratio
# 520              93.0  Action,Sci-Fi,Thriller   -499472      0.001056
# 1198            106.0  Comedy,Fantasy,Musical  -1997564      0.001218
# 2               111.0                   Drama -11985384      0.001218
# 119              91.0  Horror,Sci-Fi,Thriller  -4992444      0.001511
# 434              92.0    Comedy,Horror,Sci-Fi -32929042      0.002150

# %%
df4.tail()
# Out:
#                   movie_and_date  id release_date                  movie  \
# 776               Moonlight_2016  64   2016-10-21              Moonlight
# 455                 Get Out_2017  49   2017-02-24                Get Out
# 840   Paranormal Activity 2_2010  65   2010-10-20  Paranormal Activity 2
# 1157       The Devil Inside_2012  12   2012-01-06       The Devil Inside
# 1196            The Gallows_2015  80   2015-07-10            The Gallows
#
#       production_budget  domestic_gross  worldwide_gross release_year  index  \
# 776             1500000        27854931         65245512         2016  85930
# 455             5000000       176040665        255367951         2017  87039
# 840             3000000        84752907        177512032         2010   8964
# 1157            1000000        53262945        101759490         2012   9487
# 1196             100000        22764410         41656474         2015  35625
#
#          tconst          primary_title         original_title start_year  \
# 776   tt4975722              Moonlight              Moonlight       2016
# 455   tt5052448                Get Out                Get Out       2017
# 840   tt1536044  Paranormal Activity 2  Paranormal Activity 2       2010
# 1157  tt1560985       The Devil Inside       The Devil Inside       2012
# 1196  tt2309260            The Gallows            The Gallows       2015
#
#       runtime_minutes                   genres     profit  profit_ratio
# 776             111.0                    Drama   63745512     43.497008
# 455             104.0  Horror,Mystery,Thriller  250367951     51.073590
# 840              91.0                   Horror  174512032     59.170677
# 1157             83.0                   Horror  100759490    101.759490
# 1196             81.0  Horror,Mystery,Thriller   41556474    416.564740

# %%
plt.figure(figsize =(16,20))
sns.barplot(x='profit_ratio',y='movie_and_date',data=df4)


plt.xlim(0,416)
plt.grid(zorder=0,color='b')
plt.yticks([])
plt.xticks([0,1,416])
plt.title("profit ratio", fontsize=14)
plt.xlabel("profit ratio (income/cost)", fontsize=14)
plt.ylabel("movies", fontsize=14)
# Out:
# Text(0, 0.5, 'movies')

# %% [markdown]
# #### Outliers are making this diagram difficult to interpret
# ### Data Cleaning

# %%
df4.describe()
# Out:
#                 id  production_budget  domestic_gross  worldwide_gross  \
# count  1370.000000       1.370000e+03    1.370000e+03     1.370000e+03
# mean     50.873723       4.906805e+07    6.254886e+07     1.566260e+08
# std      28.640146       5.740899e+07    8.702606e+07     2.414072e+08
# min       1.000000       2.700000e+04    3.880000e+02     5.280000e+02
# 25%      27.000000       1.000000e+07    8.224288e+06     1.705614e+07
# 50%      51.000000       2.800000e+07    3.445786e+07     6.531321e+07
# 75%      76.000000       6.100000e+07    7.573803e+07     1.767351e+08
# max     100.000000       4.106000e+08    7.000596e+08     2.048134e+09
#
#                index  runtime_minutes        profit  profit_ratio
# count    1370.000000      1357.000000  1.370000e+03   1370.000000
# mean    33299.062774       108.285188  1.075580e+08      4.041509
# std     32615.354149        18.701518  2.000063e+08     12.547118
# min        54.000000         4.000000 -2.002376e+08      0.001056
# 25%      7221.750000        96.000000  8.264382e+05      1.099364
# 50%     20630.000000       106.000000  3.137213e+07      2.364489
# 75%     52480.250000       118.000000  1.208044e+08      4.211902
# max    145937.000000       180.000000  1.748134e+09    416.564740

# %%
# outlier? profit_ratio = 416?
df4.tail()
# Out:
#                   movie_and_date  id release_date                  movie  \
# 776               Moonlight_2016  64   2016-10-21              Moonlight
# 455                 Get Out_2017  49   2017-02-24                Get Out
# 840   Paranormal Activity 2_2010  65   2010-10-20  Paranormal Activity 2
# 1157       The Devil Inside_2012  12   2012-01-06       The Devil Inside
# 1196            The Gallows_2015  80   2015-07-10            The Gallows
#
#       production_budget  domestic_gross  worldwide_gross release_year  index  \
# 776             1500000        27854931         65245512         2016  85930
# 455             5000000       176040665        255367951         2017  87039
# 840             3000000        84752907        177512032         2010   8964
# 1157            1000000        53262945        101759490         2012   9487
# 1196             100000        22764410         41656474         2015  35625
#
#          tconst          primary_title         original_title start_year  \
# 776   tt4975722              Moonlight              Moonlight       2016
# 455   tt5052448                Get Out                Get Out       2017
# 840   tt1536044  Paranormal Activity 2  Paranormal Activity 2       2010
# 1157  tt1560985       The Devil Inside       The Devil Inside       2012
# 1196  tt2309260            The Gallows            The Gallows       2015
#
#       runtime_minutes                   genres     profit  profit_ratio
# 776             111.0                    Drama   63745512     43.497008
# 455             104.0  Horror,Mystery,Thriller  250367951     51.073590
# 840              91.0                   Horror  174512032     59.170677
# 1157             83.0                   Horror  100759490    101.759490
# 1196             81.0  Horror,Mystery,Thriller   41556474    416.564740

# %%
df4.drop(index=[1157,1196],inplace = True)

# %% [markdown]
# ### More data visualization

# %%
plt.figure(figsize =(16,20))
sns.barplot(x='profit_ratio',y='movie_and_date',data=df4)
plt.xlim(0,60)
plt.grid(zorder=0,color='b')
plt.yticks([])
plt.xticks([0,1,60])
plt.title("profit ratio", fontsize=14)
plt.xlabel("profit ratio (income/cost)", fontsize=14)
plt.ylabel("movies", fontsize=14)
# Out:
# Text(0, 0.5, 'movies')

# %% [markdown]
# #### The question is: What parameters are correlated with a movie with a low profit_ratio and a high profit_ratio?

# %% [markdown]
# ### Feature engineering
# #### make a categorical data low/medium/high based on profit_ratio <1  1-2 >2

# %%
profit_lmh = []
for profit_ratio in df4['profit_ratio']:
    if profit_ratio <1:
        profit_lmh.append('low')
    elif  profit_ratio <2:
        profit_lmh.append('medium')
    else:
        profit_lmh.append('high')
print(len(profit_lmh))
df4['profit_lmh'] = profit_lmh
df4
# Out:
# 1368
#                          movie_and_date  id release_date  \
# 520                   Higher Power_2018  67   2018-05-11
# 1198  The Ghastly Love of Johnny X_2012  74   2012-10-26
# 2            10 Days in a Madhouse_2015  48   2015-11-11
# 119                        Area 51_2015  81   2015-05-15
# 434               Freaks of Nature_2015  83   2015-10-30
# ...                                 ...  ..          ...
# 841          Paranormal Activity 3_2011  51   2011-10-21
# 248              Chernobyl Diaries_2012  18   2012-05-25
# 776                      Moonlight_2016  64   2016-10-21
# 455                        Get Out_2017  49   2017-02-24
# 840          Paranormal Activity 2_2010  65   2010-10-20
#
#                              movie  production_budget  domestic_gross  \
# 520                   Higher Power             500000             528
# 1198  The Ghastly Love of Johnny X            2000000            2436
# 2            10 Days in a Madhouse           12000000           14616
# 119                        Area 51            5000000            7556
# 434               Freaks of Nature           33000000           70958
# ...                            ...                ...             ...
# 841          Paranormal Activity 3            5000000       104028807
# 248              Chernobyl Diaries            1000000        18119640
# 776                      Moonlight            1500000        27854931
# 455                        Get Out            5000000       176040665
# 840          Paranormal Activity 2            3000000        84752907
#
#       worldwide_gross release_year  index     tconst  \
# 520               528         2018  49123  tt2924392
# 1198             2436         2012  16165  tt1754633
# 2               14616         2015  59400  tt3453052
# 119              7556         2015   8624  tt1519461
# 434             70958         2015  18716  tt1817771
# ...               ...          ...    ...        ...
# 841         207039844         2011  17175  tt1778304
# 248          42411721         2012  24683  tt1991245
# 776          65245512         2016  85930  tt4975722
# 455         255367951         2017  87039  tt5052448
# 840         177512032         2010   8964  tt1536044
#
#                      primary_title                original_title start_year  \
# 520                   Higher Power                  Higher Power       2018
# 1198  The Ghastly Love of Johnny X  The Ghastly Love of Johnny X       2012
# 2            10 Days in a Madhouse         10 Days in a Madhouse       2015
# 119                        Area 51                       Area 51       2015
# 434               Freaks of Nature              Freaks of Nature       2015
# ...                            ...                           ...        ...
# 841          Paranormal Activity 3         Paranormal Activity 3       2011
# 248              Chernobyl Diaries             Chernobyl Diaries       2012
# 776                      Moonlight                     Moonlight       2016
# 455                        Get Out                       Get Out       2017
# 840          Paranormal Activity 2         Paranormal Activity 2       2010
#
#       runtime_minutes                   genres     profit  profit_ratio  \
# 520              93.0   Action,Sci-Fi,Thriller    -499472      0.001056
# 1198            106.0   Comedy,Fantasy,Musical   -1997564      0.001218
# 2               111.0                    Drama  -11985384      0.001218
# 119              91.0   Horror,Sci-Fi,Thriller   -4992444      0.001511
# 434              92.0     Comedy,Horror,Sci-Fi  -32929042      0.002150
# ...               ...                      ...        ...           ...
# 841              83.0  Horror,Mystery,Thriller  202039844     41.407969
# 248              86.0  Horror,Mystery,Thriller   41411721     42.411721
# 776             111.0                    Drama   63745512     43.497008
# 455             104.0  Horror,Mystery,Thriller  250367951     51.073590
# 840              91.0                   Horror  174512032     59.170677
#
#      profit_lmh
# 520         low
# 1198        low
# 2           low
# 119         low
# 434         low
# ...         ...
# 841        high
# 248        high
# 776        high
# 455        high
# 840        high
#
# [1368 rows x 18 columns]

# %%
df4.reset_index(inplace=True)
df4
# Out:
#       level_0                     movie_and_date  id release_date  \
# 0         520                  Higher Power_2018  67   2018-05-11
# 1        1198  The Ghastly Love of Johnny X_2012  74   2012-10-26
# 2           2         10 Days in a Madhouse_2015  48   2015-11-11
# 3         119                       Area 51_2015  81   2015-05-15
# 4         434              Freaks of Nature_2015  83   2015-10-30
# ...       ...                                ...  ..          ...
# 1363      841         Paranormal Activity 3_2011  51   2011-10-21
# 1364      248             Chernobyl Diaries_2012  18   2012-05-25
# 1365      776                     Moonlight_2016  64   2016-10-21
# 1366      455                       Get Out_2017  49   2017-02-24
# 1367      840         Paranormal Activity 2_2010  65   2010-10-20
#
#                              movie  production_budget  domestic_gross  \
# 0                     Higher Power             500000             528
# 1     The Ghastly Love of Johnny X            2000000            2436
# 2            10 Days in a Madhouse           12000000           14616
# 3                          Area 51            5000000            7556
# 4                 Freaks of Nature           33000000           70958
# ...                            ...                ...             ...
# 1363         Paranormal Activity 3            5000000       104028807
# 1364             Chernobyl Diaries            1000000        18119640
# 1365                     Moonlight            1500000        27854931
# 1366                       Get Out            5000000       176040665
# 1367         Paranormal Activity 2            3000000        84752907
#
#       worldwide_gross release_year  index     tconst  \
# 0                 528         2018  49123  tt2924392
# 1                2436         2012  16165  tt1754633
# 2               14616         2015  59400  tt3453052
# 3                7556         2015   8624  tt1519461
# 4               70958         2015  18716  tt1817771
# ...               ...          ...    ...        ...
# 1363        207039844         2011  17175  tt1778304
# 1364         42411721         2012  24683  tt1991245
# 1365         65245512         2016  85930  tt4975722
# 1366        255367951         2017  87039  tt5052448
# 1367        177512032         2010   8964  tt1536044
#
#                      primary_title                original_title start_year  \
# 0                     Higher Power                  Higher Power       2018
# 1     The Ghastly Love of Johnny X  The Ghastly Love of Johnny X       2012
# 2            10 Days in a Madhouse         10 Days in a Madhouse       2015
# 3                          Area 51                       Area 51       2015
# 4                 Freaks of Nature              Freaks of Nature       2015
# ...                            ...                           ...        ...
# 1363         Paranormal Activity 3         Paranormal Activity 3       2011
# 1364             Chernobyl Diaries             Chernobyl Diaries       2012
# 1365                     Moonlight                     Moonlight       2016
# 1366                       Get Out                       Get Out       2017
# 1367         Paranormal Activity 2         Paranormal Activity 2       2010
#
#       runtime_minutes                   genres     profit  profit_ratio  \
# 0                93.0   Action,Sci-Fi,Thriller    -499472      0.001056
# 1               106.0   Comedy,Fantasy,Musical   -1997564      0.001218
# 2               111.0                    Drama  -11985384      0.001218
# 3                91.0   Horror,Sci-Fi,Thriller   -4992444      0.001511
# 4                92.0     Comedy,Horror,Sci-Fi  -32929042      0.002150
# ...               ...                      ...        ...           ...
# 1363             83.0  Horror,Mystery,Thriller  202039844     41.407969
# 1364             86.0  Horror,Mystery,Thriller   41411721     42.411721
# 1365            111.0                    Drama   63745512     43.497008
# 1366            104.0  Horror,Mystery,Thriller  250367951     51.073590
# 1367             91.0                   Horror  174512032     59.170677
#
#      profit_lmh
# 0           low
# 1           low
# 2           low
# 3           low
# 4           low
# ...         ...
# 1363       high
# 1364       high
# 1365       high
# 1366       high
# 1367       high
#
# [1368 rows x 19 columns]

# %%
df4.drop(columns='level_0',inplace = True)

# %%
df4
# Out:
#                          movie_and_date  id release_date  \
# 0                     Higher Power_2018  67   2018-05-11
# 1     The Ghastly Love of Johnny X_2012  74   2012-10-26
# 2            10 Days in a Madhouse_2015  48   2015-11-11
# 3                          Area 51_2015  81   2015-05-15
# 4                 Freaks of Nature_2015  83   2015-10-30
# ...                                 ...  ..          ...
# 1363         Paranormal Activity 3_2011  51   2011-10-21
# 1364             Chernobyl Diaries_2012  18   2012-05-25
# 1365                     Moonlight_2016  64   2016-10-21
# 1366                       Get Out_2017  49   2017-02-24
# 1367         Paranormal Activity 2_2010  65   2010-10-20
#
#                              movie  production_budget  domestic_gross  \
# 0                     Higher Power             500000             528
# 1     The Ghastly Love of Johnny X            2000000            2436
# 2            10 Days in a Madhouse           12000000           14616
# 3                          Area 51            5000000            7556
# 4                 Freaks of Nature           33000000           70958
# ...                            ...                ...             ...
# 1363         Paranormal Activity 3            5000000       104028807
# 1364             Chernobyl Diaries            1000000        18119640
# 1365                     Moonlight            1500000        27854931
# 1366                       Get Out            5000000       176040665
# 1367         Paranormal Activity 2            3000000        84752907
#
#       worldwide_gross release_year  index     tconst  \
# 0                 528         2018  49123  tt2924392
# 1                2436         2012  16165  tt1754633
# 2               14616         2015  59400  tt3453052
# 3                7556         2015   8624  tt1519461
# 4               70958         2015  18716  tt1817771
# ...               ...          ...    ...        ...
# 1363        207039844         2011  17175  tt1778304
# 1364         42411721         2012  24683  tt1991245
# 1365         65245512         2016  85930  tt4975722
# 1366        255367951         2017  87039  tt5052448
# 1367        177512032         2010   8964  tt1536044
#
#                      primary_title                original_title start_year  \
# 0                     Higher Power                  Higher Power       2018
# 1     The Ghastly Love of Johnny X  The Ghastly Love of Johnny X       2012
# 2            10 Days in a Madhouse         10 Days in a Madhouse       2015
# 3                          Area 51                       Area 51       2015
# 4                 Freaks of Nature              Freaks of Nature       2015
# ...                            ...                           ...        ...
# 1363         Paranormal Activity 3         Paranormal Activity 3       2011
# 1364             Chernobyl Diaries             Chernobyl Diaries       2012
# 1365                     Moonlight                     Moonlight       2016
# 1366                       Get Out                       Get Out       2017
# 1367         Paranormal Activity 2         Paranormal Activity 2       2010
#
#       runtime_minutes                   genres     profit  profit_ratio  \
# 0                93.0   Action,Sci-Fi,Thriller    -499472      0.001056
# 1               106.0   Comedy,Fantasy,Musical   -1997564      0.001218
# 2               111.0                    Drama  -11985384      0.001218
# 3                91.0   Horror,Sci-Fi,Thriller   -4992444      0.001511
# 4                92.0     Comedy,Horror,Sci-Fi  -32929042      0.002150
# ...               ...                      ...        ...           ...
# 1363             83.0  Horror,Mystery,Thriller  202039844     41.407969
# 1364             86.0  Horror,Mystery,Thriller   41411721     42.411721
# 1365            111.0                    Drama   63745512     43.497008
# 1366            104.0  Horror,Mystery,Thriller  250367951     51.073590
# 1367             91.0                   Horror  174512032     59.170677
#
#      profit_lmh
# 0           low
# 1           low
# 2           low
# 3           low
# 4           low
# ...         ...
# 1363       high
# 1364       high
# 1365       high
# 1366       high
# 1367       high
#
# [1368 rows x 18 columns]

# %% [markdown]
# #### This jupyter notebook is getting too big. Output to file to start over in a fresh notebook :Analysis_part2.ipynb

# %%
df4.to_csv('Data/df4.csv')

# %% [markdown]
# ### Let's analyze the correlation of the genre with the profit.
#
# #### Challenge: each movie has multiple genres. Need to be able to group by genre.

# %%
df5 = df4.copy()

# %% [markdown]
# ### Data cleaning

# %%
df5.isnull().any()
# Out:
# movie_and_date       False
# id                   False
# release_date         False
# movie                False
# production_budget    False
# domestic_gross       False
# worldwide_gross      False
# release_year         False
# index                False
# tconst               False
# primary_title        False
# original_title       False
# start_year           False
# runtime_minutes       True
# genres                True
# profit               False
# profit_ratio         False
# profit_lmh           False
# dtype: bool

# %%
df5.loc[df5.genres.isnull() == True]
# Out:
#              movie_and_date  id release_date              movie  \
# 116            Believe_2016  13   2016-12-02            Believe
# 282         Robin Hood_2018   9   2018-11-21         Robin Hood
# 845  The Bounty Hunter_2010  73   2010-03-19  The Bounty Hunter
#
#      production_budget  domestic_gross  worldwide_gross release_year   index  \
# 116            3500000          890303           890303         2016  142202
# 282           99000000        30824628         84747441         2018  115642
# 845           45000000        67061228        135808837         2010    8014
#
#         tconst      primary_title     original_title start_year  \
# 116  tt9347476            Believe            Believe       2016
# 282  tt6858500         Robin Hood         Robin Hood       2018
# 845  tt1472211  The Bounty Hunter  The Bounty Hunter       2010
#
#      runtime_minutes genres    profit  profit_ratio profit_lmh
# 116              NaN    NaN  -2609697      0.254372        low
# 282              NaN    NaN -14252559      0.856035        low
# 845              NaN    NaN  90808837      3.017974       high

# %%
# dropping 3 movies without genre information 
df5=df5.drop(index=[116,282,845])

# %%
df5.loc[df5.genres.isnull() == True]
# Out:
# Empty DataFrame
# Columns: [movie_and_date, id, release_date, movie, production_budget, domestic_gross, worldwide_gross, release_year, index, tconst, primary_title, original_title, start_year, runtime_minutes, genres, profit, profit_ratio, profit_lmh]
# Index: []

# %%
df5.shape
# Out:
# (1365, 18)

# %% [markdown]
# #### Make a list of each unique genre.

# %%
l= list(df5.genres.unique())
print (l)
# split each elem accoring to ","
l2=''
for elem in l:
    l2=l2 + ',' + elem
list_genres_withduplicates = l2.split(',')
list_genres_withduplicates=list_genres_withduplicates[1:]
list_genres_withduplicates
# Out:
# ['Action,Sci-Fi,Thriller', 'Comedy,Fantasy,Musical', 'Drama', 'Horror,Sci-Fi,Thriller', 'Comedy,Horror,Sci-Fi', 'Drama,Thriller', 'Action,Adventure', 'Action,Biography,Documentary', 'Mystery,Thriller', 'Horror,Thriller', 'Action,Comedy,Drama', 'Comedy', 'Drama,Music', 'Biography,Comedy,Drama', 'Comedy,Horror,Romance', 'Documentary', 'Crime,Thriller', 'Action,Drama,War', 'Comedy,Drama,Romance', 'Thriller', 'Comedy,Drama,Fantasy', 'Drama,Music,Thriller', 'Adventure,Drama', 'Drama,Mystery,Thriller', 'Drama,History,War', 'Action,Comedy,Crime', 'Crime,Drama,Thriller', 'Adventure,Horror,Sci-Fi', 'Drama,Thriller,Western', 'Action,Adventure,Comedy', 'Drama,Romance,War', 'Crime,Drama,Mystery', 'Action,Biography,Crime', 'Crime,Mystery,Thriller', 'Comedy,Drama', 'Drama,History,Thriller', 'Action,Crime,Drama', 'Horror', 'Biography,Documentary', 'Musical', 'Action,Drama', 'Biography,Crime,Drama', 'Drama,War', 'Biography,Drama,War', 'Biography,Drama,Sport', 'Comedy,Drama,Music', 'Drama,Horror,Thriller', 'Documentary,Drama,History', 'Comedy,Romance', 'Adventure,Animation,Family', 'Crime,Drama,History', 'Drama,History,Mystery', 'Drama,Mystery,Sci-Fi', 'Biography,Comedy,Crime', 'Drama,Romance', 'Biography,Documentary,Music', 'Action,Fantasy,Western', 'Crime,Drama,Romance', 'Adventure,Family,Fantasy', 'Biography,Family,Sport', 'Comedy,Music,War', 'Action,Family,Fantasy', 'Drama,Horror', 'Action,Drama,Fantasy', 'Biography,Drama,Thriller', 'Action,Fantasy,Horror', 'Biography,Drama,Romance', 'Action,Biography,Drama', 'Drama,Fantasy,Horror', 'Action,Adventure,Western', 'Drama,History,Romance', 'Drama,Family', 'Crime,Drama,Horror', 'Action,Comedy,Horror', 'Action,Crime,Thriller', 'Biography,Drama', 'Action,Comedy', 'Action,Drama,Sci-Fi', 'Adventure,Comedy,Crime', 'Fantasy,Horror,Mystery', 'Sci-Fi,Thriller', 'Action', 'Drama,Family,Music', 'Action,Drama,Mystery', 'Action,Adventure,Sci-Fi', 'Drama,Mystery,Romance', 'Drama,Fantasy', 'Action,Drama,Thriller', 'Action,Adventure,Family', 'Adventure,Drama,Thriller', 'Adventure,Drama,Family', 'Comedy,Music', 'Action,Thriller', 'Action,Crime,Horror', 'Action,Comedy,Sci-Fi', 'Music', 'Adventure,Drama,History', 'Drama,Western', 'Adventure,Comedy,Fantasy', 'Action,Adventure,Drama', 'Adventure,Animation,Comedy', 'Drama,Family,Sport', 'Adventure,Drama,Romance', 'Biography,Drama,Music', 'Action,Crime,Sci-Fi', 'Family,Horror,Romance', 'Documentary,Sport', 'Comedy,Drama,Horror', 'Biography,Drama,Family', 'Comedy,Crime,Drama', 'Horror,Mystery,Thriller', 'Action,Drama,History', 'Action,Adventure,Fantasy', 'Animation,Comedy,Drama', 'Horror,Mystery,Sci-Fi', 'Drama,Romance,Sci-Fi', 'Biography,Drama,History', 'Action,Adventure,Crime', 'Drama,Horror,Sci-Fi', 'Comedy,Crime', 'Adventure,Drama,Horror', 'Crime,Horror,Mystery', 'Drama,Sport', 'Adventure,Comedy', 'Drama,Sci-Fi', 'Action,Fantasy,Thriller', 'Adventure,Comedy,Drama', 'Action,Adventure,Thriller', 'Action,Comedy,Romance', 'Crime,Drama', 'Comedy,Drama,Musical', 'Action,Horror,Thriller', 'Drama,Horror,Mystery', 'Action,Adventure,Biography', 'Action,Horror,Sci-Fi', 'Comedy,Mystery,Sci-Fi', 'Adventure,Comedy,Family', 'Action,Crime,Mystery', 'Adventure,Fantasy', 'Drama,Fantasy,Romance', 'Fantasy', 'Comedy,Family', 'Action,Drama,Romance', 'Action,Crime,Sport', 'Action,Comedy,Family', 'Comedy,Drama,Family', 'Comedy,Horror', 'Action,Drama,Sport', 'Action,Adventure,Animation', 'Comedy,Western', 'Comedy,Fantasy', 'Action,Adventure,Romance', 'Comedy,Fantasy,Horror', 'Action,Comedy,Fantasy', 'Comedy,Family,Romance', 'Drama,Music,Musical', 'Action,Adventure,Mystery', 'Comedy,Crime,Thriller', 'Action,Comedy,Sport', 'Comedy,Drama,Sport', 'Adventure,Biography,Drama', 'Action,Adventure,Horror', 'Comedy,Romance,Sport', 'Comedy,Sci-Fi', 'Drama,History', 'Documentary,Music', 'Animation,Comedy,Family', 'Action,Sci-Fi', 'Drama,Music,Romance', 'Action,Mystery,Thriller', 'Drama,Sci-Fi,Thriller', 'Comedy,Drama,History', 'Adventure,Comedy,Music', 'Adventure,Comedy,Romance', 'Drama,Romance,Thri ...
# ['Action',
#  'Sci-Fi',
#  'Thriller',
#  'Comedy',
#  'Fantasy',
#  'Musical',
#  'Drama',
#  'Horror',
#  'Sci-Fi',
#  'Thriller',
#  'Comedy',
#  'Horror',
#  'Sci-Fi',
#  'Drama',
#  'Thriller',
#  'Action',
#  'Adventure',
#  'Action',
#  'Biography',
#  'Documentary',
#  'Mystery',
#  'Thriller',
#  'Horror',
#  'Thriller',
#  'Action',
#  'Comedy',
#  'Drama',
#  'Comedy',
#  'Drama',
#  'Music',
#  'Biography',
#  'Comedy',
#  'Drama',
#  'Comedy',
#  'Horror',
#  'Romance',
#  'Documentary',
#  'Crime',
#  'Thriller',
#  'Action',
#  'Drama',
#  'War',
#  'Comedy',
#  'Drama',
#  'Romance',
#  'Thriller',
#  'Comedy',
#  'Drama',
#  'Fantasy',
#  'Drama',
#  'Music',
#  'Thriller',
#  'Adventure',
#  'Drama',
#  'Drama',
#  'Mystery',
#  'Thriller',
#  'Drama',
#  'History',
#  'War',
#  'Action',
#  'Comedy',
#  'Crime',
#  'Crime',
#  'Drama',
#  'Thriller',
#  'Adventure',
#  'Horror',
#  'Sci-Fi',
#  'Drama',
#  'Thriller',
#  'Western',
#  'Action',
#  'Adventure',
#  'Comedy',
#  'Drama',
#  'Romance',
#  'War',
#  'Crime',
#  'Drama',
#  'Mystery',
#  'Action',
#  'Biography',
#  'Crime',
#  'Crime',
#  'Mystery',
#  'Thriller',
#  'Comedy',
#  'Drama',
#  'Drama',
#  'History',
#  'Thriller',
#  'Action',
#  'Crime',
#  'Drama',
#  'Horror',
#  'Biography',
#  'Documentary',
#  'Musical',
#  'Action',
#  'Drama',
#  'Biography',
#  'Crime',
#  'Drama',
#  'Drama',
#  'War',
#  'Biography',
#  'Drama',
#  'War',
#  'Biography',
#  'Drama',
#  'Sport',
#  'Comedy',
#  'Drama',
#  'Music',
#  'Drama',
#  'Horror',
#  'Thriller',
#  'Documentary',
#  'Drama',
#  'History',
#  'Comedy',
#  'Romance',
#  'Adventure',
#  'Animation',
#  'Family',
#  'Crime',
#  'Drama',
#  'History',
#  'Drama',
#  'History',
#  'Mystery',
#  'Drama',
#  'Mystery',
#  'Sci-Fi',
#  'Biography',
#  'Comedy',
#  'Crime',
#  'Drama',
#  'Romance',
#  'Biography',
#  'Documentary',
#  'Music',
#  'Action',
#  'Fantasy',
#  'Western',
#  'Crime',
#  'Drama',
#  'Romance',
#  'Adventure',
#  'Family',
#  'Fantasy',
#  'Biography',
#  'Family',
#  'Sport',
#  'Comedy',
#  'Music',
#  'War',
#  'Action',
#  'Family',
#  'Fantasy',
#  'Drama',
#  'Horror',
#  'Action',
#  'Drama',
#  'Fantasy',
#  'Biography',
#  'Drama',
#  'Thriller',
#  'Action',
#  'Fantasy',
#  'Horror',
#  'Biography',
#  'Drama',
#  'Romance',
#  'Action',
#  'Biography',
#  'Drama',
#  'Drama',
#  'Fantasy',
#  'Horror',
#  'Action',
#  'Adventure',
#  'Western',
#  'Drama',
#  'History',
#  'Romance',
#  'Drama',
#  'Family',
#  'Crime',
#  'Drama',
#  'Horror',
#  'Action',
#  'Comedy',
#  'Horror',
#  'Action',
#  'Crime',
#  'Thriller',
#  'Biography',
#  'Drama',
#  'Action',
#  'Comedy',
#  'Action',
#  'Drama',
#  'Sci-Fi',
#  'Adventure',
#  'Comedy',
#  'Crime',
#  'Fantasy',
#  'Horror',
#  'Mystery',
#  'Sci-Fi',
#  'Thriller',
#  'Action',
#  'Drama',
#  'Family',
#  'Music',
#  'Action',
#  'Drama',
#  'Mystery',
#  'Action',
#  'Adventure',
#  'Sci-Fi',
#  'Drama',
#  'Mystery',
#  'Romance',
#  'Drama',
#  'Fantasy',
#  'Action',
#  'Drama',
#  'Thriller',
#  'Action',
#  'Adventure',
#  'Family',
#  'Adventure',
#  'Drama',
#  'Thriller',
#  'Adventure',
#  'Drama',
#  'Family',
#  'Comedy',
#  'Music',
#  'Action',
#  'Thriller',
#  'Action',
#  'Crime',
#  'Horror',
#  'Action',
#  'Comedy',
#  'Sci-Fi',
#  'Music',
#  'Adventure',
#  'Drama',
#  'History',
#  'Drama',
#  'Western',
#  'Adventure',
#  'Comedy',
#  'Fantasy',
#  'Action',
#  'Adventure',
#  'Drama',
#  'Adventure',
#  'Animation',
#  'Comedy',
#  'Drama',
#  'Family',
#  'Sport',
#  'Adventure',
#  'Drama',
#  'Romance',
#  'Biography',
#  'Drama',
#  'Music',
#  'Action',
#  'Crime',
#  'Sci-Fi',
#  'Family',
#  'Horror',
#  'Romance',
#  'Documentary',
#  'Sport',
#  'Comedy',
#  'Drama',
#  'Horror',
#  'Biography',
#  'Drama',
#  'Family',
#  'Comedy',
#  'Crime',
#  'Drama',
#  'Horror',
#  'Mystery',
#  'Thriller',
#  'Action',
#  'Drama',
#  'History',
#  'Action',
#  'Adventure',
#  'Fantasy',
#  'Animation',
#  'Comedy',
#  'Drama',
#  'Horror',
#  'Mystery',
#  'Sci-Fi',
#  'Drama',
#  'Romance',
#  'Sci-Fi',
#  'Biography',
#  'Drama',
#  'History',
#  'Action',
#  'Adventure',
#  'Crime',
#  'Drama',
#  'Horror',
#  'Sci-Fi',
#  'Comedy',
#  'Crime',
#  'Adventure',
#  'Drama',
#  'Horror',
#  'Crime',
#  'Horror',
#  'Mystery',
#  'Drama',
#  'Sport',
#  'Adventure',
#  'Comedy',
#  'Drama',
#  'Sci-Fi',
#  'Action',
#  'Fantasy',
#  'Thriller',
#  'Adventure',
#  'Comedy',
#  'Drama',
#  'Action',
#  'Adventure',
#  'Thriller',
#  'Action',
#  'Comedy',
#  'Romance',
#  'Crime',
#  'Drama',
#  'Comedy',
#  'Drama',
#  'Musical',
#  'Action',
#  'Horror',
#  'Thriller',
#  'Drama',
#  'Horror',
#  'Mystery',
#  'Action',
#  'Adventure',
#  'Biography',
#  'Action',
#  'Horror',
#  'Sci-Fi',
#  'Comedy',
#  'Mystery',
#  'Sci-Fi',
#  'Adventure',
#  'Comedy',
#  'Family',
#  'Action',
#  'Crime',
#  'Mystery',
#  'Adventure',
#  'Fantasy',
#  'Drama',
#  'Fantasy',
#  'Romance',
#  'Fantasy',
#  'Comedy',
#  'Family',
#  'Action',
#  'Drama',
#  'Romance',
#  'Action',
#  'Crime',
#  'Sport',
#  'Action',
#  'Comedy',
#  'Family',
#  'Comedy',
#  'Drama',
#  'Family',
#  'Comedy',
#  'Horror',
#  'Action',
#  'Drama',
#  'Sport',
#  'Action',
#  'Adventure',
#  'Animation',
#  'Comedy',
#  'Western',
#  'Comedy',
#  'Fantasy',
#  'Action',
#  'Adventure',
#  'Romance',
#  'Comedy',
#  'Fantasy',
#  'Horror',
#  'Action',
#  'Comedy',
#  'Fantasy',
#  'Comedy',
#  'Family',
#  'Romance',
#  'Drama',
#  'Music',
#  'Musical',
#  'Action',
#  'Adventure',
#  'Mystery',
#  'Comedy',
#  'Crime',
#  'Thriller',
#  'Action',
#  'Comedy',
#  'Sport',
#  'Comedy',
#  'Drama',
#  'Sport',
#  'Adventure',
#  'Biography',
#  'Drama',
#  'Action',
#  'Adventure',
#  'Horror',
#  'Comedy',
#  'Romance',
#  'Sport',
#  'Comedy',
#  'Sci-Fi',
#  'Drama',
#  'History',
#  'Documentary',
#  'Music',
#  'Animation',
#  'Comedy',
#  'Family',
#  'Action',
#  'Sci-Fi',
#  'Drama',
#  'Music',
#  'Romance',
#  'Action',
#  'Mystery',
#  'Thriller',
#  'Drama',
#  'Sci-Fi',
#  'Thriller',
#  'Comedy',
#  'Drama',
#  'History',
#  'Adventure',
#  'Comedy',
#  'Music',
#  'Adventure',
#  'Comedy',
#  'Romance',
#  'Drama',
#  'Romance',
#  'Thriller',
#  'Comedy',
#  'Fantasy',
#  'Romance',
#  'Comedy',
#  'Family',
#  'Fantasy',
#  'Drama',
#  'Mystery',
#  'War',
#  'Comedy',
#  'Documentary',
#  'Action',
#  'Drama',
#  'Family',
#  'Horror',
#  'Mystery',
#  'Action',
#  'Animation',
#  'Comedy',
#  'Romance',
#  'Sci-Fi',
#  'Thriller',
#  'Adventure',
#  'Comedy',
#  'Sci-Fi',
#  'Comedy',
#  'Sport',
#  'Action',
#  'Crime',
#  'Action',
#  'Biography',
#  'Comedy',
#  'Comedy',
#  'Crime',
#  'Romance',
#  'Action',
#  'Fantasy',
#  'War',
#  'Adventure',
#  'Mystery',
#  'Sci-Fi',
#  'Adventure',
#  'Family',
#  'Sci-Fi',
#  'Comedy',
#  'Music',
#  'Romance',
#  'Drama',
#  'Fantasy',
#  'Mystery',
#  'Crime',
#  'Documentary',
#  'Adventure',
#  'Drama',
#  'Sci-Fi',
#  'Biography',
#  'Drama',
#  'Musical',
#  'Adventure',
#  'Biography',
#  'Comedy',
#  'Fantasy',
#  'Musical',
#  'Mystery',
#  'Sci-Fi',
#  'Thriller',
#  'Adventure',
#  'Drama',
#  'Fantasy',
#  'Drama',
#  'Family',
#  'Fantasy',
#  'Comedy',
#  'Fantasy',
#  'Sci-Fi',
#  'Fantasy',
#  'Horror',
#  'Thriller',
#  'Comedy',
#  'Mystery',
#  'Comedy',
#  'Drama',
#  'Mystery',
#  'Drama',
#  'Fantasy',
#  'Music',
#  'Adventure',
#  'Drama',
#  'Western',
#  'Family',
#  'Fantasy',
#  'Musical',
#  'Drama',
#  'Mystery',
#  'Adventure',
#  'Horror',
#  'Mystery',
#  'Action',
#  'Comedy',
#  'Documentary',
#  'Action',
#  'Mystery',
#  'Sci-Fi',
#  'Biography',
#  'Drama',
#  'Fantasy']

# %%
unique_genres=[]
for elem in list_genres_withduplicates:
    if elem not in unique_genres:
        unique_genres.append(elem)
unique_genres
# Out:
# ['Action',
#  'Sci-Fi',
#  'Thriller',
#  'Comedy',
#  'Fantasy',
#  'Musical',
#  'Drama',
#  'Horror',
#  'Adventure',
#  'Biography',
#  'Documentary',
#  'Mystery',
#  'Music',
#  'Romance',
#  'Crime',
#  'War',
#  'History',
#  'Western',
#  'Sport',
#  'Animation',
#  'Family']

# %%
# create columns for each genre to flag movie genre: Fill in with True if movie belongs to the genre 

for genre in unique_genres:
    l=[]
    for i in df5.index:
        if genre in df5['genres'][i]:
            l.append(True)
        else:
            l.append (False)
    df5[genre]=l

df5.iloc[9, 14:]
# Out:
# genres          Mystery,Thriller
# profit                   -846744
# profit_ratio          0.00383059
# profit_lmh                   low
# Family                     False
# Action                     False
# Sci-Fi                     False
# Thriller                    True
# Comedy                     False
# Fantasy                    False
# Musical                    False
# Drama                      False
# Horror                     False
# Adventure                  False
# Biography                  False
# Documentary                False
# Mystery                     True
# Music                      False
# Romance                    False
# Crime                      False
# War                        False
# History                    False
# Western                    False
# Sport                      False
# Animation                  False
# Name: 9, dtype: object

# %% [markdown]
# #### Now I am able to analyse profitability according to genre

# %%
df5.shape
# Out:
# (1365, 39)

# %%
dico_low={}
dico_high={}
for genre in  unique_genres:
    dico_low [genre]=len(df5[(df5[genre] == True) & (df5['profit_lmh'] == 'low') ])
    dico_high[genre]=len(df5[(df5[genre] == True) & (df5['profit_lmh'] == 'high') ])

# %%
dico_low
# Out:
# {'Action': 81,
#  'Sci-Fi': 23,
#  'Thriller': 56,
#  'Comedy': 81,
#  'Fantasy': 20,
#  'Musical': 3,
#  'Drama': 189,
#  'Horror': 36,
#  'Adventure': 42,
#  'Biography': 42,
#  'Documentary': 16,
#  'Mystery': 21,
#  'Music': 14,
#  'Romance': 35,
#  'Crime': 59,
#  'War': 9,
#  'History': 13,
#  'Western': 5,
#  'Sport': 10,
#  'Animation': 6,
#  'Family': 15}

# %%
dico_high
# Out:
# {'Action': 233,
#  'Sci-Fi': 87,
#  'Thriller': 143,
#  'Comedy': 291,
#  'Fantasy': 67,
#  'Musical': 4,
#  'Drama': 337,
#  'Horror': 94,
#  'Adventure': 221,
#  'Biography': 63,
#  'Documentary': 22,
#  'Mystery': 77,
#  'Music': 31,
#  'Romance': 106,
#  'Crime': 100,
#  'War': 6,
#  'History': 18,
#  'Western': 2,
#  'Sport': 13,
#  'Animation': 72,
#  'Family': 47}

# %%
dico_low.keys() == dico_high.keys()
# Out:
# True

# %%
dflow=pd.DataFrame.from_dict(dico_low,orient='index',columns=['number_of_movies_lowp'])
dfhigh=pd.DataFrame.from_dict(dico_high,orient='index',columns=['number_of_movies_highp'])

# %%
# dflow['profit_flag'] = 1
# dfhigh['profit_flag']=2


# df6=dflow.append(dfhigh,ignore_index=True)

df6=dflow.join(dfhigh,how='inner')
df6
# Out:
#              number_of_movies_lowp  number_of_movies_highp
# Action                          81                     233
# Sci-Fi                          23                      87
# Thriller                        56                     143
# Comedy                          81                     291
# Fantasy                         20                      67
# Musical                          3                       4
# Drama                          189                     337
# Horror                          36                      94
# Adventure                       42                     221
# Biography                       42                      63
# Documentary                     16                      22
# Mystery                         21                      77
# Music                           14                      31
# Romance                         35                     106
# Crime                           59                     100
# War                              9                       6
# History                         13                      18
# Western                          5                       2
# Sport                           10                      13
# Animation                        6                      72
# Family                          15                      47

# %%
df6['total_by_genre']=df6['number_of_movies_lowp']+df6['number_of_movies_highp']
df6['fraction_highp_by_genre']=df6['number_of_movies_highp']/df6['total_by_genre']
df6['fraction_lowp_by_genre'] =df6['number_of_movies_lowp'] /df6['total_by_genre']
df6.reset_index(inplace=True)
df6=df6.rename(columns={'index':'genre'})
df6['ratio_num_highlow']= df6 ['fraction_highp_by_genre'] / df6['fraction_lowp_by_genre']
df6=df6.sort_values(by='ratio_num_highlow',ascending=True)
df6
# Out:
#           genre  number_of_movies_lowp  number_of_movies_highp  \
# 17      Western                      5                       2
# 15          War                      9                       6
# 18        Sport                     10                      13
# 5       Musical                      3                       4
# 10  Documentary                     16                      22
# 16      History                     13                      18
# 9     Biography                     42                      63
# 14        Crime                     59                     100
# 6         Drama                    189                     337
# 12        Music                     14                      31
# 2      Thriller                     56                     143
# 7        Horror                     36                      94
# 0        Action                     81                     233
# 13      Romance                     35                     106
# 20       Family                     15                      47
# 4       Fantasy                     20                      67
# 3        Comedy                     81                     291
# 11      Mystery                     21                      77
# 1        Sci-Fi                     23                      87
# 8     Adventure                     42                     221
# 19    Animation                      6                      72
#
#     total_by_genre  fraction_highp_by_genre  fraction_lowp_by_genre  \
# 17               7                 0.285714                0.714286
# 15              15                 0.400000                0.600000
# 18              23                 0.565217                0.434783
# 5                7                 0.571429                0.428571
# 10              38                 0.578947                0.421053
# 16              31                 0.580645                0.419355
# 9              105                 0.600000                0.400000
# 14             159                 0.628931                0.371069
# 6              526                 0.640684                0.359316
# 12              45                 0.688889                0.311111
# 2              199                 0.718593                0.281407
# 7              130                 0.723077                0.276923
# 0              314                 0.742038                0.257962
# 13             141                 0.751773                0.248227
# 20              62                 0.758065                0.241935
# 4               87                 0.770115                0.229885
# 3              372                 0.782258                0.217742
# 11              98                 0.785714                0.214286
# 1              110                 0.790909                0.209091
# 8              263                 0.840304                0.159696
# 19              78                 0.923077                0.076923
#
#     ratio_num_highlow
# 17           0.400000
# 15           0.666667
# 18           1.300000
# 5            1.333333
# 10           1.375000
# 16           1.384615
# 9            1.500000
# 14           1.694915
# 6            1.783069
# 12           2.214286
# 2            2.553571
# 7            2.611111
# 0            2.876543
# 13           3.028571
# 20           3.133333
# 4            3.350000
# 3            3.592593
# 11           3.666667
# 1            3.782609
# 8            5.261905
# 19          12.000000

# %% [markdown]
# #### Visualization of profitability according to genre

# %%
df6['x']=1

fig,ax = plt.subplots(nrows=1,ncols=2,figsize=(5,16))

plt.subplot(121)
sns.scatterplot (x='x',y='genre',
                 size='fraction_lowp_by_genre',data=df6 , sizes=(10,2000),legend=False)
plt.xticks([])
plt.xlabel("UNsuccessful movies", fontsize=14)
plt.yticks(fontsize=14)

plt.subplot(122)
sns.scatterplot (x='x',y='genre',
                 size='fraction_highp_by_genre',data=df6 , sizes=(10,2000),legend=False)
plt.xticks([])
plt.yticks([])
plt.xlabel("Successful movies", fontsize=14)

# plt.xlim(0,10)

# plt.grid(zorder=0,color='b')
# plt.yticks([])
# plt.xticks([0,1,10])
# plt.title("profitability of 1000 randomly chosen movies (1991-2019)", fontsize=14)
# plt.xlabel("profit ratio (income/cost)", fontsize=14)
# plt.ylabel("movies", fontsize=14)

# plt.xticks(rotation=45)
# plt.yticks([])
# plt.xlabel("Genre", fontsize=14)
# plt.ylabel("", fontsize=14)

plt.title("Relative success according to genre. Unsuccessful movies(left) vs.successful movies(right)", fontsize=18)

plt.show()

# %%
### Conclusion:
#### Genres and movie success are corelated.  
#### The five genres with highest rates of successful movies are : Animation, Adventure, Sci-Fi, Mystery and Comedy. 
#### By contrast, the 5 genres with the worst rate of success are:  Documentary, Musical, Sport, War and Western
