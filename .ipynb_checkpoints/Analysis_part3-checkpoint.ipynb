# %% [markdown]
# # This is the third part of the final project of module 1
# #### We are starting over from a dataframe called df1 that was exported in the jupyter notebook analysis_part1.ipynb
# ### GOAL : Determine if the movie business is a profitable business using repeated random selections of existing movies

# %%
import pandas as pd

# %%
df1= pd.read_csv('./Data/df1.csv')
df1
# Out:
#       Unnamed: 0  id release_date  \
# 0              0   1   2009-12-18
# 1              1   2   2011-05-20
# 2              2   3   2019-06-07
# 3              3   4   2015-05-01
# 4              4   5   2017-12-15
# ...          ...  ..          ...
# 5777        5777  78   2018-12-31
# 5778        5778  79   1999-04-02
# 5779        5779  80   2005-07-13
# 5780        5780  81   2015-09-29
# 5781        5781  82   2005-08-05
#
#                                             movie production_budget  \
# 0                                          Avatar      $425,000,000
# 1     Pirates of the Caribbean: On Stranger Tides      $410,600,000
# 2                                    Dark Phoenix      $350,000,000
# 3                         Avengers: Age of Ultron      $330,600,000
# 4               Star Wars Ep. VIII: The Last Jedi      $317,000,000
# ...                                           ...               ...
# 5777                                       Red 11            $7,000
# 5778                                    Following            $6,000
# 5779                Return to the Land of Wonders            $5,000
# 5780                         A Plague So Pleasant            $1,400
# 5781                            My Date With Drew            $1,100
#
#      domestic_gross worldwide_gross  release_year  \
# 0      $760,507,625  $2,776,345,279          2009
# 1      $241,063,875  $1,045,663,875          2011
# 2       $42,762,350    $149,762,350          2019
# 3      $459,005,868  $1,403,013,963          2015
# 4      $620,181,382  $1,316,721,747          2017
# ...             ...             ...           ...
# 5777             $0              $0          2018
# 5778        $48,482        $240,495          1999
# 5779         $1,338          $1,338          2005
# 5780             $0              $0          2015
# 5781       $181,041        $181,041          2005
#
#                                         movie_and_date
# 0                                          Avatar_2009
# 1     Pirates of the Caribbean: On Stranger Tides_2011
# 2                                    Dark Phoenix_2019
# 3                         Avengers: Age of Ultron_2015
# 4               Star Wars Ep. VIII: The Last Jedi_2017
# ...                                                ...
# 5777                                       Red 11_2018
# 5778                                    Following_1999
# 5779                Return to the Land of Wonders_2005
# 5780                         A Plague So Pleasant_2015
# 5781                            My Date With Drew_2005
#
# [5782 rows x 9 columns]

# %% [markdown]
# ### Feature Engineering : profit  and profit_ratio
#
# Let's use worldwide_gross / production_budget / movie_and_date to identify profitable movies
#
# Need to remove $ and , signs from worldwide_gross and production_budget
#
# Need to make sure dollar amounts make sense
#
# The goal is to create features telling us if a movie was successful (ie profitable) or not.

# %%
# make sure all $ amounts are string
df1.astype({'production_budget':'str', 'domestic_gross':'str', 'worldwide_gross':'str',})
# Out:
#       Unnamed: 0  id release_date  \
# 0              0   1   2009-12-18
# 1              1   2   2011-05-20
# 2              2   3   2019-06-07
# 3              3   4   2015-05-01
# 4              4   5   2017-12-15
# ...          ...  ..          ...
# 5777        5777  78   2018-12-31
# 5778        5778  79   1999-04-02
# 5779        5779  80   2005-07-13
# 5780        5780  81   2015-09-29
# 5781        5781  82   2005-08-05
#
#                                             movie production_budget  \
# 0                                          Avatar      $425,000,000
# 1     Pirates of the Caribbean: On Stranger Tides      $410,600,000
# 2                                    Dark Phoenix      $350,000,000
# 3                         Avengers: Age of Ultron      $330,600,000
# 4               Star Wars Ep. VIII: The Last Jedi      $317,000,000
# ...                                           ...               ...
# 5777                                       Red 11            $7,000
# 5778                                    Following            $6,000
# 5779                Return to the Land of Wonders            $5,000
# 5780                         A Plague So Pleasant            $1,400
# 5781                            My Date With Drew            $1,100
#
#      domestic_gross worldwide_gross  release_year  \
# 0      $760,507,625  $2,776,345,279          2009
# 1      $241,063,875  $1,045,663,875          2011
# 2       $42,762,350    $149,762,350          2019
# 3      $459,005,868  $1,403,013,963          2015
# 4      $620,181,382  $1,316,721,747          2017
# ...             ...             ...           ...
# 5777             $0              $0          2018
# 5778        $48,482        $240,495          1999
# 5779         $1,338          $1,338          2005
# 5780             $0              $0          2015
# 5781       $181,041        $181,041          2005
#
#                                         movie_and_date
# 0                                          Avatar_2009
# 1     Pirates of the Caribbean: On Stranger Tides_2011
# 2                                    Dark Phoenix_2019
# 3                         Avengers: Age of Ultron_2015
# 4               Star Wars Ep. VIII: The Last Jedi_2017
# ...                                                ...
# 5777                                       Red 11_2018
# 5778                                    Following_1999
# 5779                Return to the Land of Wonders_2005
# 5780                         A Plague So Pleasant_2015
# 5781                            My Date With Drew_2005
#
# [5782 rows x 9 columns]

# %%
df1.index
# Out:
# RangeIndex(start=0, stop=5782, step=1)

# %%
type(df1.production_budget[0])
# Out:
# str

# %%
# removing $ and , from $ amounts
df1['production_budget']= [df1['production_budget'][x][1:]for x in df1.index]
df1['domestic_gross']= [df1['domestic_gross'][x][1:]for x in df1.index]
df1['worldwide_gross']= [df1['worldwide_gross'][x][1:]for x in df1.index]
df1['production_budget']= [df1['production_budget'][x].replace(',','')for x in df1.index]
df1['domestic_gross']= [df1['domestic_gross'][x].replace(',','')for x in df1.index]
df1['worldwide_gross']= [df1['worldwide_gross'][x].replace(',','')for x in df1.index]

# %%
df1.head()
# Out:
#    Unnamed: 0  id release_date                                        movie  \
# 0           0   1   2009-12-18                                       Avatar
# 1           1   2   2011-05-20  Pirates of the Caribbean: On Stranger Tides
# 2           2   3   2019-06-07                                 Dark Phoenix
# 3           3   4   2015-05-01                      Avengers: Age of Ultron
# 4           4   5   2017-12-15            Star Wars Ep. VIII: The Last Jedi
#
#   production_budget domestic_gross worldwide_gross  release_year  \
# 0         425000000      760507625      2776345279          2009
# 1         410600000      241063875      1045663875          2011
# 2         350000000       42762350       149762350          2019
# 3         330600000      459005868      1403013963          2015
# 4         317000000      620181382      1316721747          2017
#
#                                      movie_and_date
# 0                                       Avatar_2009
# 1  Pirates of the Caribbean: On Stranger Tides_2011
# 2                                 Dark Phoenix_2019
# 3                      Avengers: Age of Ultron_2015
# 4            Star Wars Ep. VIII: The Last Jedi_2017

# %%
df1=df1.astype({'production_budget':'float', 'domestic_gross':'float', 'worldwide_gross':'float'})
df1.head()
# Out:
#    Unnamed: 0  id release_date                                        movie  \
# 0           0   1   2009-12-18                                       Avatar
# 1           1   2   2011-05-20  Pirates of the Caribbean: On Stranger Tides
# 2           2   3   2019-06-07                                 Dark Phoenix
# 3           3   4   2015-05-01                      Avengers: Age of Ultron
# 4           4   5   2017-12-15            Star Wars Ep. VIII: The Last Jedi
#
#    production_budget  domestic_gross  worldwide_gross  release_year  \
# 0        425000000.0     760507625.0     2.776345e+09          2009
# 1        410600000.0     241063875.0     1.045664e+09          2011
# 2        350000000.0      42762350.0     1.497624e+08          2019
# 3        330600000.0     459005868.0     1.403014e+09          2015
# 4        317000000.0     620181382.0     1.316722e+09          2017
#
#                                      movie_and_date
# 0                                       Avatar_2009
# 1  Pirates of the Caribbean: On Stranger Tides_2011
# 2                                 Dark Phoenix_2019
# 3                      Avengers: Age of Ultron_2015
# 4            Star Wars Ep. VIII: The Last Jedi_2017

# %%
df1.describe()
# Out:
#        Unnamed: 0           id  production_budget  domestic_gross  \
# count  5782.00000  5782.000000       5.782000e+03    5.782000e+03
# mean   2890.50000    50.372363       3.158776e+07    4.187333e+07
# std    1669.26396    28.821076       4.181208e+07    6.824060e+07
# min       0.00000     1.000000       1.100000e+03    0.000000e+00
# 25%    1445.25000    25.000000       5.000000e+06    1.429534e+06
# 50%    2890.50000    50.000000       1.700000e+07    1.722594e+07
# 75%    4335.75000    75.000000       4.000000e+07    5.234866e+07
# max    5781.00000   100.000000       4.250000e+08    9.366622e+08
#
#        worldwide_gross  release_year
# count     5.782000e+03   5782.000000
# mean      9.148746e+07   2003.967139
# std       1.747200e+08     12.724386
# min       0.000000e+00   1915.000000
# 25%       4.125415e+06   2000.000000
# 50%       2.798445e+07   2007.000000
# 75%       9.764584e+07   2012.000000
# max       2.776345e+09   2020.000000

# %%
# removing rows with sero $ values
df1=df1.loc[ (df1['production_budget']!=0) & (df1['domestic_gross']!=0) & (df1['worldwide_gross']!=0)]

# %%
df1.shape
# Out:
# (5234, 9)

# %%
# min release year is 1915. Analysis should focus on recent movies. Lower limit set to 1990.
df1=df1.loc[ (df1['release_year'] > 1990)]

# %%
df1.shape
# Out:
# (4657, 9)

# %%
# making sure: no more zeroes and release_year>1990
df1.describe()
# Out:
#         Unnamed: 0           id  production_budget  domestic_gross  \
# count  4657.000000  4657.000000       4.657000e+03    4.657000e+03
# mean   2599.817479    50.334335       3.680598e+07    4.690444e+07
# std    1622.731006    28.622988       4.455780e+07    7.194079e+07
# min       0.000000     1.000000       1.100000e+03    3.880000e+02
# 25%    1186.000000    26.000000       8.000000e+06    3.688560e+06
# 50%    2484.000000    50.000000       2.050000e+07    2.216344e+07
# 75%    3915.000000    75.000000       5.000000e+07    5.860701e+07
# max    5781.000000   100.000000       4.250000e+08    9.366622e+08
#
#        worldwide_gross  release_year
# count     4.657000e+03   4657.000000
# mean      1.056597e+08   2006.739102
# std       1.880919e+08      6.808942
# min       4.010000e+02   1991.000000
# 25%       8.120148e+06   2002.000000
# 50%       3.801787e+07   2007.000000
# 75%       1.173781e+08   2012.000000
# max       2.776345e+09   2019.000000

# %%
df1.reset_index()
# Out:
#       index  Unnamed: 0  id release_date  \
# 0         0           0   1   2009-12-18
# 1         1           1   2   2011-05-20
# 2         2           2   3   2019-06-07
# 3         3           3   4   2015-05-01
# 4         4           4   5   2017-12-15
# ...     ...         ...  ..          ...
# 4652   5775        5775  76   2006-05-26
# 4653   5776        5776  77   2004-12-31
# 4654   5778        5778  79   1999-04-02
# 4655   5779        5779  80   2005-07-13
# 4656   5781        5781  82   2005-08-05
#
#                                             movie  production_budget  \
# 0                                          Avatar        425000000.0
# 1     Pirates of the Caribbean: On Stranger Tides        410600000.0
# 2                                    Dark Phoenix        350000000.0
# 3                         Avengers: Age of Ultron        330600000.0
# 4               Star Wars Ep. VIII: The Last Jedi        317000000.0
# ...                                           ...                ...
# 4652                                       Cavite             7000.0
# 4653                              The Mongol King             7000.0
# 4654                                    Following             6000.0
# 4655                Return to the Land of Wonders             5000.0
# 4656                            My Date With Drew             1100.0
#
#       domestic_gross  worldwide_gross  release_year  \
# 0        760507625.0     2.776345e+09          2009
# 1        241063875.0     1.045664e+09          2011
# 2         42762350.0     1.497624e+08          2019
# 3        459005868.0     1.403014e+09          2015
# 4        620181382.0     1.316722e+09          2017
# ...              ...              ...           ...
# 4652         70071.0     7.164400e+04          2006
# 4653           900.0     9.000000e+02          2004
# 4654         48482.0     2.404950e+05          1999
# 4655          1338.0     1.338000e+03          2005
# 4656        181041.0     1.810410e+05          2005
#
#                                         movie_and_date
# 0                                          Avatar_2009
# 1     Pirates of the Caribbean: On Stranger Tides_2011
# 2                                    Dark Phoenix_2019
# 3                         Avengers: Age of Ultron_2015
# 4               Star Wars Ep. VIII: The Last Jedi_2017
# ...                                                ...
# 4652                                       Cavite_2006
# 4653                              The Mongol King_2004
# 4654                                    Following_1999
# 4655                Return to the Land of Wonders_2005
# 4656                            My Date With Drew_2005
#
# [4657 rows x 10 columns]

# %%
print(df1.columns)
df1.drop(columns={'Unnamed: 0', 'id'},inplace= True)
print(df1.columns)
# Out:
# Index(['Unnamed: 0', 'id', 'release_date', 'movie', 'production_budget',
#        'domestic_gross', 'worldwide_gross', 'release_year', 'movie_and_date'],
#       dtype='object')
# Index(['release_date', 'movie', 'production_budget', 'domestic_gross',
#        'worldwide_gross', 'release_year', 'movie_and_date'],
#       dtype='object')

# %%
df1.tail()
# Out:
#      release_date                          movie  production_budget  \
# 5775   2006-05-26                         Cavite             7000.0
# 5776   2004-12-31                The Mongol King             7000.0
# 5778   1999-04-02                      Following             6000.0
# 5779   2005-07-13  Return to the Land of Wonders             5000.0
# 5781   2005-08-05              My Date With Drew             1100.0
#
#       domestic_gross  worldwide_gross  release_year  \
# 5775         70071.0          71644.0          2006
# 5776           900.0            900.0          2004
# 5778         48482.0         240495.0          1999
# 5779          1338.0           1338.0          2005
# 5781        181041.0         181041.0          2005
#
#                           movie_and_date
# 5775                         Cavite_2006
# 5776                The Mongol King_2004
# 5778                      Following_1999
# 5779  Return to the Land of Wonders_2005
# 5781              My Date With Drew_2005

# %%
# feature engineering :profit
df1['profit'] = df1['worldwide_gross']-df1['production_budget']
df1.head()
# Out:
#   release_date                                        movie  \
# 0   2009-12-18                                       Avatar
# 1   2011-05-20  Pirates of the Caribbean: On Stranger Tides
# 2   2019-06-07                                 Dark Phoenix
# 3   2015-05-01                      Avengers: Age of Ultron
# 4   2017-12-15            Star Wars Ep. VIII: The Last Jedi
#
#    production_budget  domestic_gross  worldwide_gross  release_year  \
# 0        425000000.0     760507625.0     2.776345e+09          2009
# 1        410600000.0     241063875.0     1.045664e+09          2011
# 2        350000000.0      42762350.0     1.497624e+08          2019
# 3        330600000.0     459005868.0     1.403014e+09          2015
# 4        317000000.0     620181382.0     1.316722e+09          2017
#
#                                      movie_and_date        profit
# 0                                       Avatar_2009  2.351345e+09
# 1  Pirates of the Caribbean: On Stranger Tides_2011  6.350639e+08
# 2                                 Dark Phoenix_2019 -2.002376e+08
# 3                      Avengers: Age of Ultron_2015  1.072414e+09
# 4            Star Wars Ep. VIII: The Last Jedi_2017  9.997217e+08

# %%
# feature engineering :profit_ratio
# profit_ratio < 1 means money lost
# profit_ratio > 1 means profit
df1['profit_ratio'] = df1['worldwide_gross']/df1['production_budget']
df1.sort_values(by = 'profit_ratio',inplace=True)
df1.head()
# Out:
#      release_date                           movie  production_budget  \
# 4081   2010-05-21              Perrierâs Bounty          6600000.0
# 3818   2015-05-08                      Skin Trade          9000000.0
# 2152   1997-08-24  The Grimm Brothers' Snow White         26000000.0
# 5027   1993-01-01          Ed and his Dead Mother          1800000.0
# 1242   2013-11-01                      Mr. Nobody         46500000.0
#
#       domestic_gross  worldwide_gross  release_year  \
# 4081           828.0            828.0          2010
# 3818          1242.0           1242.0          2015
# 2152          5000.0           5000.0          1997
# 5027           673.0            673.0          1993
# 1242          3622.0          22254.0          2013
#
#                            movie_and_date      profit  profit_ratio
# 4081              Perrierâs Bounty_2010  -6599172.0      0.000125
# 3818                      Skin Trade_2015  -8998758.0      0.000138
# 2152  The Grimm Brothers' Snow White_1997 -25995000.0      0.000192
# 5027          Ed and his Dead Mother_1993  -1799327.0      0.000374
# 1242                      Mr. Nobody_2013 -46477746.0      0.000479

# %%
df1.tail(20)
# Out:
#      release_date                     movie  production_budget  \
# 5706   1998-07-10                        Pi            68000.0
# 4589   1997-08-13            The Full Monty          3500000.0
# 4247   2002-04-19  My Big Fat Greek Wedding          5000000.0
# 5156   2004-10-29                       Saw          1200000.0
# 5459   2009-04-23                      Home           500000.0
# 5211   2012-01-06          The Devil Inside          1000000.0
# 5680   2006-09-29         Facing the Giants           100000.0
# 5430   2004-08-06                Open Water           500000.0
# 5507   2004-06-11         Napoleon Dynamite           400000.0
# 5746   1997-08-01     In the Company of Men            25000.0
# 5774   2004-10-08                    Primer             7000.0
# 5742   1994-10-19                    Clerks            27000.0
# 5656   2007-05-16                      Once           150000.0
# 5781   2005-08-05         My Date With Drew             1100.0
# 5715   1995-08-09     The Brothers McMullen            50000.0
# 5773   1993-02-26               El Mariachi             7000.0
# 5709   2004-05-07             Super Size Me            65000.0
# 5406   1999-07-14   The Blair Witch Project           600000.0
# 5679   2015-07-10               The Gallows           100000.0
# 5492   2009-09-25       Paranormal Activity           450000.0
#
#       domestic_gross  worldwide_gross  release_year  \
# 5706       3221152.0        4678513.0          1998
# 4589      45950122.0      261249383.0          1997
# 4247     241438208.0      374890034.0          2002
# 5156      55968727.0      103880027.0          2004
# 5459         15433.0       44793168.0          2009
# 5211      53262945.0      101759490.0          2012
# 5680      10178331.0       10243159.0          2006
# 5430      30500882.0       55518641.0          2004
# 5507      44540956.0       46122713.0          2004
# 5746       2883661.0        2883661.0          1997
# 5774        424760.0         841926.0          2004
# 5742       3073428.0        3894240.0          1994
# 5656       9445857.0       23323631.0          2007
# 5781        181041.0         181041.0          2005
# 5715      10426506.0       10426506.0          1995
# 5773       2040920.0        2041928.0          1993
# 5709      11529368.0       22233808.0          2004
# 5406     140539099.0      248300000.0          1999
# 5679      22764410.0       41656474.0          2015
# 5492     107918810.0      194183034.0          2009
#
#                      movie_and_date       profit  profit_ratio
# 5706                        Pi_1998    4610513.0     68.801662
# 4589            The Full Monty_1997  257749383.0     74.642681
# 4247  My Big Fat Greek Wedding_2002  369890034.0     74.978007
# 5156                       Saw_2004  102680027.0     86.566689
# 5459                      Home_2009   44293168.0     89.586336
# 5211          The Devil Inside_2012  100759490.0    101.759490
# 5680         Facing the Giants_2006   10143159.0    102.431590
# 5430                Open Water_2004   55018641.0    111.037282
# 5507         Napoleon Dynamite_2004   45722713.0    115.306782
# 5746     In the Company of Men_1997    2858661.0    115.346440
# 5774                    Primer_2004     834926.0    120.275143
# 5742                    Clerks_1994    3867240.0    144.231111
# 5656                      Once_2007   23173631.0    155.490873
# 5781         My Date With Drew_2005     179941.0    164.582727
# 5715     The Brothers McMullen_1995   10376506.0    208.530120
# 5773               El Mariachi_1993    2034928.0    291.704000
# 5709             Super Size Me_2004   22168808.0    342.058585
# 5406   The Blair Witch Project_1999  247700000.0    413.833333
# 5679               The Gallows_2015   41556474.0    416.564740
# 5492       Paranormal Activity_2009  193733034.0    431.517853

# %% [markdown]
# #### Some production_budget don't make sense. Imposing a lower treshold of $64,000 (because the budget of SuperSizeMe is 65,000 and is believable)

# %%
df1=df1.loc[df1['production_budget'] > 64000]

# %%
df1.reset_index(inplace=True)
df1
# Out:
#       index release_date                           movie  production_budget  \
# 0      4081   2010-05-21              Perrierâs Bounty          6600000.0
# 1      3818   2015-05-08                      Skin Trade          9000000.0
# 2      2152   1997-08-24  The Grimm Brothers' Snow White         26000000.0
# 3      5027   1993-01-01          Ed and his Dead Mother          1800000.0
# 4      1242   2013-11-01                      Mr. Nobody         46500000.0
# ...     ...          ...                             ...                ...
# 4612   5656   2007-05-16                            Once           150000.0
# 4613   5709   2004-05-07                   Super Size Me            65000.0
# 4614   5406   1999-07-14         The Blair Witch Project           600000.0
# 4615   5679   2015-07-10                     The Gallows           100000.0
# 4616   5492   2009-09-25             Paranormal Activity           450000.0
#
#       domestic_gross  worldwide_gross  release_year  \
# 0              828.0            828.0          2010
# 1             1242.0           1242.0          2015
# 2             5000.0           5000.0          1997
# 3              673.0            673.0          1993
# 4             3622.0          22254.0          2013
# ...              ...              ...           ...
# 4612       9445857.0       23323631.0          2007
# 4613      11529368.0       22233808.0          2004
# 4614     140539099.0      248300000.0          1999
# 4615      22764410.0       41656474.0          2015
# 4616     107918810.0      194183034.0          2009
#
#                            movie_and_date       profit  profit_ratio
# 0                 Perrierâs Bounty_2010   -6599172.0      0.000125
# 1                         Skin Trade_2015   -8998758.0      0.000138
# 2     The Grimm Brothers' Snow White_1997  -25995000.0      0.000192
# 3             Ed and his Dead Mother_1993   -1799327.0      0.000374
# 4                         Mr. Nobody_2013  -46477746.0      0.000479
# ...                                   ...          ...           ...
# 4612                            Once_2007   23173631.0    155.490873
# 4613                   Super Size Me_2004   22168808.0    342.058585
# 4614         The Blair Witch Project_1999  247700000.0    413.833333
# 4615                     The Gallows_2015   41556474.0    416.564740
# 4616             Paranormal Activity_2009  193733034.0    431.517853
#
# [4617 rows x 10 columns]

# %%
len(df1)
# Out:
# 4617

# %%
df1.describe()
# Out:
#              index  production_budget  domestic_gross  worldwide_gross  \
# count  4617.000000       4.617000e+03    4.617000e+03     4.617000e+03
# mean   2572.532814       3.712465e+07    4.730503e+07     1.065689e+08
# std    1602.928215       4.461813e+07    7.212220e+07     1.886500e+08
# min       0.000000       6.500000e+04    3.880000e+02     4.230000e+02
# 25%    1176.000000       8.000000e+06    4.002293e+06     8.589831e+06
# 50%    2461.000000       2.100000e+07    2.253030e+07     3.851285e+07
# 75%    3885.000000       5.000000e+07    5.888419e+07     1.185565e+08
# max    5709.000000       4.250000e+08    9.366622e+08     2.776345e+09
#
#        release_year        profit  profit_ratio
# count   4617.000000  4.617000e+03   4617.000000
# mean    2006.762833  6.944429e+07      3.697709
# std        6.805469  1.576655e+08     13.550861
# min     1991.000000 -2.002376e+08      0.000125
# 25%     2002.000000 -1.982104e+06      0.707504
# 50%     2007.000000  1.391284e+07      1.819044
# 75%     2012.000000  7.400879e+07      3.658676
# max     2019.000000  2.351345e+09    431.517853

# %%
np.median(df1.profit_ratio)
# Out:
# 1.8190436363636364

# %% [markdown]
# # Visualization

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# 4617 movies is a lot to draw.
# random selection of 1000 for drawing purposes.

n=np.random.randint(0,4617,1000)
df2=df1.copy(deep=True)
df2=df2.iloc[n]
df2.sort_values(by = 'profit_ratio',inplace=True)

plt.figure(figsize =(16,20))
sns.barplot(x='profit_ratio',y='movie_and_date',data=df2)
plt.xlim(0,10)
plt.grid(zorder=0,color='b')
plt.yticks([])
plt.xticks([0,1,10])
plt.title("profitability of 1000 randomly chosen movies (1991-2019)", fontsize=14)
plt.xlabel("profit ratio (income/cost)", fontsize=14)
plt.ylabel("movies", fontsize=14)
# Out:
# Text(0, 0.5, 'movies')

# %% [markdown]
# ### Goal: Determine if movie is a good business.
# #### Idea: pick random movies from df1 and get average profit_ratio

# %%
# function to get avg profit ratio from p random movies based on dataframe df1
def random_avg_profit(p):
# pick p movies randomly
    random_movie_indexes=np.random.randint(0,len(df1),p)
# get the corresponding profit_ratio values and average them
    avg =0
    for i in random_movie_indexes:
        avg += (df1['profit_ratio'][i])/p
    return avg

# %%
# run random_avg_profit 1000 times and graph the values
# that corresponds to 1000 possible sets of 10 movies.
# ie. 1000 possible outcomes for the 10 first movies of our new movie company

random_avg_profit_list=[]
for i in range(1000):
    random_avg_profit(10)
    random_avg_profit_list.append(random_avg_profit(10))
df5 = pd.DataFrame(list(enumerate(random_avg_profit_list)))
df5
df5.columns=['movie_index','avg_profit_ratio']
df5['movie_index'] = df5['movie_index']+1
df5
# Out:
#      movie_index  avg_profit_ratio
# 0              1          1.612336
# 1              2          4.989851
# 2              3          1.899341
# 3              4          4.549537
# 4              5          5.067220
# ..           ...               ...
# 995          996          3.146410
# 996          997          2.778749
# 997          998          2.577555
# 998          999          2.842128
# 999         1000          3.566434
#
# [1000 rows x 2 columns]

# %%
fig = plt.figure(figsize=(16,5))
sns.lineplot(x='movie_index',y = 'avg_profit_ratio',data = df5)


plt.ylim(0,20)
plt.grid(zorder=0,color='black')
m = np.median(df5['avg_profit_ratio'])
plt.yticks([0,m,20])
plt.title("1000  outcomes for profitability of 10 randomly chosen movies", fontsize=14)
ylabl='profit ratio (income/cost). Median =' + str(round(m,2))
plt.ylabel(ylabl, fontsize=14)
plt.xlabel("each x is a different outcome of a random choice of 10 movies", fontsize=14)
# Out:
# Text(0.5, 0, 'each x is a different outcome of a random choice of 10 movies')

# %% [markdown]
# ### Conclusion:
# #### Getting into the movie business is a good choice as the level of profits is generally high: With 10 randomly chosen movies, our min and max profit ratio are ~.9 to ~11.6, and the median is close to 3. Pretty good!
#
# ### let's try a different simulation
# #### In the simulation above, we repeatedly chose 10 random movies. Now, let's vary the number of movies we chose. Let's generate 10000 numbers between 1 and 100. Each of these 20000 numbers is a number p of movies that we will randomly select from df1. Then we calculate the corresponding average profit_ratio for this selection of p movies (using the function random_avg_profit(p))

# %%
number_of_movies_list=[]
avg_profit_ratio_list=[]

for number_of_movies in np.random.randint(1,100,20000):
# find the corresponding random movies and avg profit ratio in df1
    number_of_movies_list.append(number_of_movies)
    avg_profit_ratio_list.append(random_avg_profit(number_of_movies))

# make a dataframe out of the results
df6 = pd.DataFrame( list(zip(number_of_movies_list,avg_profit_ratio_list)) )

df6.columns=['number_of_movies','avg_profit_ratio']

df6.sort_values(by='number_of_movies')
df6
# Out:
#        number_of_movies  avg_profit_ratio
# 0                     6          3.265961
# 1                    93          2.413206
# 2                    73          3.894678
# 3                    80          2.784023
# 4                    31          2.529281
# ...                 ...               ...
# 19995                81          6.903317
# 19996                19          5.405872
# 19997                49          3.274261
# 19998                11          4.342324
# 19999                71          3.863985
#
# [20000 rows x 2 columns]

# %%
fig = plt.figure(figsize=(10,7))
sns.lineplot(x='number_of_movies',y = 'avg_profit_ratio',data = df6)


plt.grid(zorder=0,color='black')
m = np.mean(df6['avg_profit_ratio'])
plt.yticks([0,m,10])
ylabl='profit ratio (income/cost). Mean =' + str(round(m,2))
plt.ylabel(ylabl, fontsize=14)
plt.title("profitability for randomly chosen movies", fontsize=14)
plt.xlabel("number of movies (randomly chosen)", fontsize=14)
# Out:
# Text(0.5, 0, 'number of movies (randomly chosen)')

# %% [markdown]
# ### Conclusion:
# #### Again we see that the movie business is quite lucrative. After 20 movies, we are almost certain to reach a profit ratio higher than 3.
# ### New question:
# #### For each profit ratio value, how many of the 20000 outcomes gave that value?

# %%
# First, let's redo the simulation using only number of movies > 30 
number_of_movies_list2=[]
avg_profit_ratio_list2=[]

for number_of_movies in np.random.randint(31,100,20000):
# find the corresponding random movies and avg profit ratio in df1
    number_of_movies_list2.append(number_of_movies)
    avg_profit_ratio_list2.append(random_avg_profit(number_of_movies))

# make a dataframe out of the results
df6b = pd.DataFrame( list(zip(number_of_movies_list2,avg_profit_ratio_list2)) )

df6b.columns=['number_of_movies','avg_profit_ratio']

df6b.sort_values(by='number_of_movies')
print(df6b.shape)

# round profit ratio to create commmon values we can group by
df6b['avg_profit_ratio'] = round(df6b['avg_profit_ratio'], 1)
# Out:
# (20000, 2)

# %%
df6b.head()
# Out:
#    number_of_movies  avg_profit_ratio
# 0                86               3.4
# 1                40               3.2
# 2                78               3.6
# 3                70               3.6
# 4                44               4.3

# %%
profit_ratio_list=[]
number_of_occurences_list=[]
# scanning over profit ratio values between 0 and 15, every .1
# for each profit value, counting number of occurences in df6
for i in range(0,150):
    profit_ratio_list.append(i/10)
    number_of_occurences_list.append(df6b.loc[df6b['avg_profit_ratio'] == i/10].shape[0])

# create a new dataframe with the number of occurences 
d = {'profit_ratio': profit_ratio_list, 'number_of_occur': number_of_occurences_list}
df7=pd.DataFrame(d)
df7
# Out:
#      profit_ratio  number_of_occur
# 0             0.0                0
# 1             0.1                0
# 2             0.2                0
# 3             0.3                0
# 4             0.4                0
# ..            ...              ...
# 145          14.5                3
# 146          14.6                2
# 147          14.7                3
# 148          14.8                3
# 149          14.9                5
#
# [150 rows x 2 columns]

# %%
fig = plt.figure(figsize=(13,5))
sns.lineplot(x='profit_ratio',y = 'number_of_occur',data = df7)

plt.grid(zorder=0,color='black')
m = np.mean(df6b['avg_profit_ratio'])
plt.xticks([0,3,m,15])
xlabl='profit ratio (income/cost). Mean =' + str(round(m,2))




plt.title("distribution of profit ratio ", fontsize=14)
plt.ylabel("number of outcomes", fontsize=14)
plt.xlabel(xlabl, fontsize=14)
# Out:
# Text(0.5, 0, 'profit ratio (income/cost). Mean =3.67')

# %% [markdown]
# ### Conclusion:
# #### when we take random selections of movies from our data, we get a normal distribution of their profit ratio. The central value reached the most often is about 3.

# %% [markdown]
# ### Note:
# #### The Central Theorem predicts that this normal distribution should be centered around the population mean ~3.67. THe discrepancy observed here should be the subject of further study.
